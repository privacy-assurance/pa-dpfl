# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv('/home/mirwais/Desktop/datasets in desktop/Payroll data/Payroll data.csv')
# Out:
# /tmp/ipykernel_7422/4126164029.py:2: DtypeWarning: Columns (15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/home/mirwais/Desktop/datasets in desktop/Payroll data/Payroll data.csv')

# %%
# Set style for seaborn plots
sns.set(style="whitegrid")

# %%
user_counts = dataset.groupby('user_id').size()
user_counts.plot(kind='bar', width=0.7)  # Adjust the width parameter as needed

# Add values on top of each bar with a bit of space
for i, count in enumerate(user_counts):
    plt.text(i, count + 0.1, f'{count}', ha='center', va='bottom')

# Customize axis labels
plt.xlabel('User_ID (Clients)')
plt.ylabel('Number of Data Samples')

# Save the plot to a PDF file
plt.savefig('/home/mirwais/Downloads/Payroll_data_distribution.pdf', bbox_inches='tight')
plt.show()

# %%
# Histogram of Salary
plt.figure(figsize=(10, 6))
sns.histplot(data['Salary'], bins=20, kde=True)
plt.title('Histogram of Salary')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot of Salary
plt.figure(figsize=(10, 6))
sns.boxplot(x=data['Salary'])
plt.title('Boxplot of Salary')
plt.xlabel('Salary')
plt.show()

# %%
# Count plot of Gender
plt.figure(figsize=(5, 5))
sns.countplot(x='Gender', data=data)
plt.title('Employees by Gender')
plt.show()

# %%
# Count plot of MaritalStatus
plt.figure(figsize=(8, 5))
sns.countplot(x='MaritalStatus', data=data)
plt.title('Employees by MaritalStatus')
plt.show()

# %%
# Bar plot of Province
plt.figure(figsize=(12, 6))
sns.countplot(y='Province', data=data)
plt.title('Employees by Province')
plt.xlabel('Count')
plt.show()

# %%
# Boxplot of Salary by Gender
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Salary', data=data)
plt.title('Boxplot of Salary by Gender')
plt.xlabel('Gender')
plt.ylabel('Salary')
plt.show()

# %%
# Boxplot of Salary by MaritalStatus
plt.figure(figsize=(10, 6))
sns.boxplot(x='MaritalStatus', y='Salary', data=data)
plt.title('Salary by MaritalStatus')
plt.xlabel('MaritalStatus')
plt.ylabel('Salary')
plt.show()

# %%
# Boxplot of Salary by Province
plt.figure(figsize=(12, 8))
sns.boxplot(x='Province', y='Salary', data=data)
plt.title('Salary by Province')
plt.xlabel('Province')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %%
#  Bar plot of Position
plt.figure(figsize=(12, 6))
sns.countplot(y='Position', data=data)
plt.title('Bar plot of Position')
plt.xlabel('Count')
plt.show()

# %%
# Bar plot of PositionTitle
plt.figure(figsize=(12, 6))
sns.countplot(y='Positiontitle', data=data)
plt.title('Bar plot of PositionTitle')
plt.xlabel('Count')
plt.show()

# %%
#  Bar plot of Grade
plt.figure(figsize=(10, 6))
sns.countplot(y='Grade', data=data)
plt.title('Employees by Grade')
plt.xlabel('Count')
plt.show()

# %%
#  Bar plot of Step
plt.figure(figsize=(10, 6))
sns.countplot(y='Step', data=data)
plt.title('Employees by Step')
plt.xlabel('Count')
plt.show()

# %%
#  Count plot of Status
plt.figure(figsize=(8, 5))
sns.countplot(x='Status', data=data)
plt.title('Eployees Status')
plt.show()

# %%
# Boxplot of Salary by Status
plt.figure(figsize=(10, 6))
sns.boxplot(x='Status', y='Salary', data=data)
plt.title('Salary by Status')
plt.xlabel('Status')
plt.ylabel('Salary')
plt.show()

# %%
# Bar plot of Gender by MaritalStatus
plt.figure(figsize=(8, 5))
sns.countplot(x='MaritalStatus', hue='Gender', data=data)
plt.title('Employees Gender by MaritalStatus')
plt.show()

# %%
#  Bar plot of Province by Gender
plt.figure(figsize=(12, 6))
sns.countplot(y='Province', hue='Gender', data=data)
plt.title('Employees by Province and Gender')
plt.xlabel('Count')
plt.show()

# %%
# Boxplot of Salary by Position
plt.figure(figsize=(12, 6))
sns.boxplot(x='Position', y='Salary', data=data)
plt.title('Salary by Position')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %%
# Boxplot of Salary by PositionTitle
plt.figure(figsize=(12, 6))
sns.boxplot(x='Positiontitle', y='Salary', data=data)
plt.title('Salary by PositionTitle')
plt.xlabel('PositionTitle')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar plot of Grade by Gender
plt.figure(figsize=(10, 6))
sns.countplot(y='Grade', hue='Gender', data=data)
plt.title('Grade by Gender')
plt.xlabel('Count')
plt.show()

# %%
# Plot 28: Bar plot of Step by Gender
plt.figure(figsize=(10, 6))
sns.countplot(y='Step', hue='Gender', data=data)
plt.title('Step by Gender')
plt.xlabel('Count')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /tmp/ipykernel_7422/3990060065.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
