# %%
import pandas as pd
import random
import seaborn as sns
import numpy as np
import tensorflow as tf
import tensorflow_privacy as tfp
import tensorflow_federated as tff
from sklearn.preprocessing import LabelEncoder , StandardScaler

import matplotlib.pyplot as plt
import logging
import warnings

# Filter out the specified warnings
warnings.filterwarnings("ignore", message="divide by zero encountered in divide", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="invalid value encountered in subtract", category=RuntimeWarning)
# Set the logging level to suppress DeprecationWarnings
logging.captureWarnings(True)
logging.getLogger("absl").setLevel(logging.ERROR)
# Out:
# 2024-03-21 10:03:40.715755: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-21 10:03:40.987040: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-21 10:03:40.987118: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-21 10:03:40.989102: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-21 10:03:41.128001: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-21 10:03:41.129383: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-21 10:03:42.253255: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = pd.read_csv("/home/mirwais/Desktop/datasets in desktop/Payroll data/Payroll data.csv")
features = list(dataset.drop(['user_id','Status','contractT'], axis=1).columns)

dataset.head()
# Out:
# WARNING:py.warnings:/tmp/ipykernel_5736/3343249160.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("/home/mirwais/Desktop/datasets in desktop/Payroll data/Payroll data.csv")
#   user_id Married_Status contractT position Positiontitle  Salary  Grade  \
# 0    West      Unmarried     رسمی      معلم         معلم     6500      6
# 1    West      Unmarried     اجیر      اجیر   اجیرخدماتی     5300      8
# 2    West        Married     اجیر      معلم         معلم        0      7
# 3    West        Married     رسمی     مامور         مدیر     9900      4
# 4    West        Married     اجیر      معلم         معلم        0      7
#
#    Step         DoB    JoinDate   Status
# 0     1  1348-01-01  1394-06-01     Fire
# 1     4  1349-01-01  1385-01-27  Present
# 2     0  1352-01-01  1000-01-01     Fire
# 3     1  1369-01-01  1393-01-26  Present
# 4     0  1349-01-01  1000-01-01     Fire

# %%
user_counts = dataset.groupby('user_id').size()
user_counts.plot(kind='bar', width=0.7)  # Adjust the width parameter as needed

# Add values on top of each bar with a bit of space
for i, count in enumerate(user_counts):
    plt.text(i, count + 0.1, f'{count}', ha='center', va='bottom')

# Customize axis labels
plt.xlabel('User_ID (Clients)')
plt.ylabel('Number of Data Samples')

# Save the plot to a PDF file
plt.savefig('/home/mirwais/Downloads/Payroll_data_distribution.pdf', bbox_inches='tight')
plt.show()

# %%
dataset.dropna(axis=0, inplace=True)

# %%
# Encode categorical variables
label_encoder = LabelEncoder()
for column in dataset.select_dtypes(include=["object"]).columns:
    dataset[column] = label_encoder.fit_transform(dataset[column])

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the selected feature columns
dataset[features] = scaler.fit_transform(dataset[features])

# %%
dataset.head()
# Out:
#    user_id  Married_Status  contractT  position  Positiontitle    Salary  \
# 0        6        1.214660          7  0.484741       0.544235  0.253535
# 1        6        1.214660          1 -2.328058      -1.895384 -0.045277
# 2        6       -0.765169          1  0.484741       0.544235 -1.365027
# 3        6       -0.765169          7 -0.921659      -0.370622  1.100167
# 4        6       -0.765169          1  0.484741       0.544235 -1.365027
#
#       Grade      Step       DoB  JoinDate  Status
# 0 -0.344223 -0.507664 -0.892313  0.635108       0
# 1  0.122772  0.051139 -0.827632 -0.263151       1
# 2 -0.110726 -0.693932 -0.632006 -2.461199       0
# 3 -0.811218 -0.507664  0.546693  0.508812       1
# 4 -0.110726 -0.693932 -0.827632 -2.461199       0

# %%
NUM_EPOCHS =20
BATCH_SIZE = 20
SHUFFLE_BUFFER = 100
PREFETCH_BUFFER = 10
ROUNDS =30

features = list(dataset.drop(['user_id'], axis=1).columns)
input_shape = len(features)
client_ids = dataset['user_id'].unique()
num_clients = len(client_ids)

# %%
#@title utilities
def custom_train_test_split(df, split_percentage=0.7):
    split_size = int(len(df) * split_percentage)
    indices = list(range(len(df)))
    random.shuffle(indices)

    # Split the indices into two parts
    train_indices = indices[:split_size]
    test_indices = indices[split_size:]

    # Create training and testing DataFrames
    df_train = df.iloc[train_indices]
    df_test = df.iloc[test_indices]

    return df_train, df_test

def create_client_datasets(dataset):
    dataset_copy = dataset.copy()
    grouped = dataset_copy.groupby('user_id')
    client_data_dict = {}

    for client_id, group in grouped:
        datasets = tf.data.Dataset.from_tensor_slices((group[features], group.pop('Status'))).repeat(NUM_EPOCHS).shuffle(SHUFFLE_BUFFER, seed=1).batch(
      BATCH_SIZE).prefetch(PREFETCH_BUFFER)

        client_data_dict[client_id] = datasets

    # Create a client data object
    client_data = tff.simulation.datasets.ClientData.from_clients_and_tf_fn(
        client_ids=list(client_data_dict.keys()),
        serializable_dataset_fn=lambda client_id: client_data_dict[client_id]
    )

    return client_data

def preprocess(client_dataset,features):
    dataset_copy = client_dataset.copy()
    tf_dataset = tf.data.Dataset.from_tensor_slices((dataset_copy[features], dataset_copy.pop('Status'))).repeat(NUM_EPOCHS).shuffle(SHUFFLE_BUFFER, seed=1).batch(
      BATCH_SIZE).prefetch(PREFETCH_BUFFER)
    return tf_dataset


def make_federated_data(dataset,client_ids):
    client_data = create_client_datasets(dataset)
    return [client_data.create_tf_dataset_for_client(x) for x in client_ids]

# %%
normal_dataset, shadow_dataset = custom_train_test_split(dataset, split_percentage=0.5)
df_train, df_test = custom_train_test_split(normal_dataset, split_percentage=0.7)
shadow_df_train, shadow_df_test = custom_train_test_split(shadow_dataset, split_percentage=0.7)

# %%
federated_data = make_federated_data(df_train, client_ids)
print(f'Number of client datasets: {len(federated_data)}')
print(f'First dataset: {federated_data[0]}')
# Out:
# Number of client datasets: 7
# First dataset: <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 10), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
#@title Add F1 score metric
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.false_positives = self.add_weight(name='fp', initializer='zeros')
        self.false_negatives = self.add_weight(name='fn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.round(y_pred), tf.float32)

        tp = tf.reduce_sum(y_true * y_pred)
        fp = tf.reduce_sum((1 - y_true) * y_pred)
        fn = tf.reduce_sum(y_true * (1 - y_pred))

        self.true_positives.assign_add(tp)
        self.false_positives.assign_add(fp)
        self.false_negatives.assign_add(fn)

    def result(self):
        precision = self.true_positives / (self.true_positives + self.false_positives + tf.keras.backend.epsilon())
        recall = self.true_positives / (self.true_positives + self.false_negatives + tf.keras.backend.epsilon())
        f1 = 2 * (precision * recall) / (precision + recall + tf.keras.backend.epsilon())
        return f1

def create_keras_model():
    return tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(input_shape=(input_shape,), name='input_layer'),
        tf.keras.layers.Dense(60, activation='relu', name='dense_1'),
        tf.keras.layers.Dense(1, activation='sigmoid', name='output_layer')
    ])

def model_fn():
    keras_model = create_keras_model()
    tff_metrics = [
        tf.keras.metrics.BinaryAccuracy(),
        tf.keras.metrics.AUC(),
        tf.keras.metrics.AUC(curve="pr"),
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
        F1Score()
    ]

    return tff.learning.models.from_keras_model(
        keras_model,
        input_spec=federated_data[0].element_spec,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=tff_metrics
    )

# %%
#@title Normal Federated Functions

@tff.tf_computation
def server_init():
    model = model_fn()
    return model.trainable_variables

@tf.function
def client_update(model, dataset, server_weights, client_optimizer):
    client_weights = model.trainable_variables
    tf.nest.map_structure(lambda x, y: x.assign(y), client_weights, server_weights)

    for batch in dataset:
        with tf.GradientTape() as tape:
            outputs = model.forward_pass(batch)

        grads = tape.gradient(outputs.loss, client_weights)
        grads_and_vars = zip(grads, client_weights)
        client_optimizer.apply_gradients(grads_and_vars)

    return client_weights

whimsy_model = model_fn()
tf_dataset_type = tff.SequenceType(whimsy_model.input_spec)
model_weights_type = server_init.type_signature.result
federated_server_type = tff.FederatedType(model_weights_type, tff.SERVER)
federated_dataset_type = tff.FederatedType(tf_dataset_type, tff.CLIENTS)
metrics = [tf.keras.metrics.BinaryAccuracy(), F1Score()]

@tf.function
def server_update(model, mean_client_weights):
    model_weights = model.trainable_variables
    tf.nest.map_structure(lambda x, y: x.assign(y), model_weights, mean_client_weights)
    return model_weights

@tff.federated_computation
def initialize_fn():
    return tff.federated_value(server_init(), tff.SERVER)

@tff.tf_computation(tf_dataset_type, model_weights_type)
def client_update_fn(tf_dataset, server_weights):
    model = model_fn()
    client_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
    return client_update(model, tf_dataset, server_weights, client_optimizer)

@tff.tf_computation(model_weights_type)
def server_update_fn(mean_client_weights):
    model = model_fn()
    return server_update(model, mean_client_weights)

@tff.federated_computation(federated_server_type, federated_dataset_type)
def next_fn(server_weights, federated_dataset):
    server_weights_at_client = tff.federated_broadcast(server_weights)
    client_weights = tff.federated_map(client_update_fn, (federated_dataset, server_weights_at_client))
    mean_client_weights = tff.federated_mean(client_weights)
    server_weights = tff.federated_map(server_update_fn, mean_client_weights)
    return server_weights, client_weights

def evaluate(server_state):
    keras_model = create_keras_model()
    keras_model.compile(
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=metrics
    )
    keras_model.set_weights(server_state)
    test_df = preprocess(df_test, features)
    return keras_model.evaluate(test_df, verbose=0)

# %%
#@title Federated Training
normal_federated_algorithm = tff.templates.IterativeProcess(
    initialize_fn=initialize_fn,
    next_fn=next_fn
)
server_state = normal_federated_algorithm.initialize()

clients = {}
history = []

for round in range(ROUNDS):
    server_state , client_weights = normal_federated_algorithm.next(server_state, federated_data)
    clients[round] = client_weights
    loss, accuracy , f1_score_value  = evaluate(server_state)
    history.append([loss, accuracy, f1_score_value])
    print(f'Round: {round}')
    print(f"\nTest Loss: {loss:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    print(f"Test F1 Score: {f1_score_value:.4f}")
    print('.'*70)
# Out:
# 2024-02-29 17:23:50.526854: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.526942: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.689182: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.689266: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.774976: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.775036: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.780188: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.780235: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.785822: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.785868: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.790052: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.790097: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.797829: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.797910: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.807499: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.807551: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.815081: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.815127: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 17:23:50.829340: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 17:23:50.829397: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# Round: 0
#
# Test Loss: 0.0081
# Test Accuracy: 0.9995
# Test F1 Score: 0.9997
# ......................................................................
# Round: 1
#
# Test Loss: 0.0015
# Test Accuracy: 0.9998
# Test F1 Score: 0.9998
# ......................................................................
# Round: 2
#
# Test Loss: 0.0007
# Test Accuracy: 0.9998
# Test F1 Score: 0.9999
# ......................................................................
# Round: 3
#
# Test Loss: 0.0004
# Test Accuracy: 0.9999
# Test F1 Score: 0.9999
# ......................................................................
# Round: 4
#
# Test Loss: 0.0003
# Test Accuracy: 0.9999
# Test F1 Score: 0.9999
# ......................................................................
# Round: 5
#
# Test Loss: 0.0002
# Test Accuracy: 0.9999
# Test F1 Score: 0.9999
# ......................................................................
# Round: 6
#
# Test Loss: 0.0002
# Test Accuracy: 0.9999
# Test F1 Score: 0.9999
# ......................................................................
# Round: 7
#
# Test Loss: 0.0002
# Test Accuracy: 0.9999
# Test F1 Score: 1.0000
# ......................................................................
# Round: 8
#
# Test Loss: 0.0001
# Test Accuracy: 0.9999
# Test F1 Score: 1.0000
# ......................................................................
# Round: 9
#
# Test Loss: 0.0001
# Test Accuracy: 0.9999
# Test F1 Score: 1.0000
# ......................................................................
# Round: 10
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 11
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 12
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 13
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 14
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 15
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 16
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 17
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 18
#
# Test Loss: 0.0001
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 19
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 20
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 21
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 22
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 23
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 24
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 25
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 26
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 27
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 28
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................
# Round: 29
#
# Test Loss: 0.0000
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# ......................................................................

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Create a PDF file to save the plots
pdf_filename = "federated_training_logs.pdf"
pdf_pages = PdfPages(pdf_filename)

# Your code for generating and plotting the three subplots goes here
#@title Normal Federated Training Logs
# Extract individual arrays for loss, accuracy, and f1
loss_values, accuracy_values, f1_values = zip(*history)

# Create a figure to hold the subplots
fig = plt.figure(figsize=(12, 4))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(loss_values, label='Loss', marker='.')
# plt.title('Test Loss')
plt.xlabel('Rounds')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 2)
plt.plot(accuracy_values, label='Accuracy', marker='.')
# plt.title('Test Accuracy')
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Plot F1 Score
plt.subplot(1, 3, 3)
plt.plot(f1_values, label='F1 Score', marker='.')
# plt.title('Test F1 Score')
plt.xlabel('Rounds')
plt.ylabel('F1 Score')
plt.legend()

plt.tight_layout()

# Save the figure into the PDF file
pdf_pages.savefig(fig)

# Save Loss plot to PDF
with PdfPages('/home/mirwais/Downloads/FL_Model.pdf') as pdf:
    pdf.savefig(fig, bbox_inches='tight')  # Specify the figure to save

plt.show()
    
# # Close the PDF file
# pdf_pages.close()

# # Display a message indicating that the PDF file has been saved
# print(f"Plots saved to {pdf_filename}")

# %%
normal_client_weights = clients[list(clients)[-1]]

# %%
#@title Noisy Federated Functions

# Define the L2 norm clip
L2_norm_clip = 0.1
float_type = tff.TensorType(dtype=tf.float32)

@tf.function
def noisy_client_update(model, dataset, server_weights, client_optimizer, noise_multiplier):
    client_weights = model.trainable_variables
    tf.nest.map_structure(lambda x, y: x.assign(y), client_weights, server_weights)

    for batch in dataset:
        # Add Gaussian noise to the input batch
        noisy_batch = (
            tf.cast(batch[0], tf.float32) + tf.random.normal(shape=tf.shape(batch[0]), stddev=noise_multiplier),
            tf.cast(batch[1], tf.float32) + tf.random.normal(shape=tf.shape(batch[1]), stddev=noise_multiplier)
        )

        with tf.GradientTape() as tape:
            outputs = model.forward_pass(noisy_batch)

        grads = tape.gradient(outputs.loss, client_weights)

        # Clip gradients
        clipped_gradients = [tf.clip_by_norm(g, L2_norm_clip) for g in grads]

        # Add Gaussian noise
        noisy_gradients = [g + tf.random.normal(shape=tf.shape(g), stddev=L2_norm_clip * noise_multiplier)
                           for g in clipped_gradients]

        # Apply the gradient using a client optimizer.
        client_optimizer.apply_gradients(zip(noisy_gradients, client_weights))

    return client_weights

@tf.function
def noisy_server_update(model, mean_client_weights):
    model_weights = model.trainable_variables
    tf.nest.map_structure(lambda x, y: x.assign(y), model_weights, mean_client_weights)
    return model_weights

@tff.tf_computation(tf_dataset_type, model_weights_type, float_type)
def noisy_client_update_fn(tf_dataset, server_weights, noise_multiplier):
    model = model_fn()
    client_optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
    return noisy_client_update(model, tf_dataset, server_weights, client_optimizer, noise_multiplier)

@tff.tf_computation(model_weights_type)
def noisy_server_update_fn(mean_client_weights):
    model = model_fn()
    return noisy_server_update(model, mean_client_weights)

@tff.tf_computation
def noisy_server_init():
    model = model_fn()
    return model.trainable_variables

@tff.federated_computation
def noisy_initialize_fn():
    return tff.federated_value(server_init(), tff.SERVER)

@tff.federated_computation(federated_server_type, federated_dataset_type, float_type)
def noisy_next_fn(server_weights, federated_dataset, noise_multiplier):
    # Broadcast the server weights to the clients.
    server_weights_at_client = tff.federated_broadcast(server_weights)
    noise_federated = tff.federated_value(noise_multiplier, tff.CLIENTS)

    # Each client computes their updated weights.
    client_weights = tff.federated_map(noisy_client_update_fn, (federated_dataset, server_weights_at_client, noise_federated))

    # The server averages these updates.
    mean_client_weights = tff.federated_mean(client_weights)

    # The server updates its model.
    server_weights = tff.federated_map(noisy_server_update_fn, mean_client_weights)
    return server_weights, client_weights

def run_noisy_federated_algorithm(noise, federated_data, ROUNDS):
    # Define the noisy_federated_algorithm
    noisy_federated_algorithm = tff.templates.IterativeProcess(
        initialize_fn=noisy_initialize_fn,
        next_fn=noisy_next_fn
    )

    # Reset the server state for each noise value
    server_state = noisy_federated_algorithm.initialize()

    # Evaluate initial server state
    loss, accuracy, f1_score_value = evaluate(server_state)
    print(f"Initial Loss: {loss}, Accuracy: {accuracy}, F1 Score: {f1_score_value}")
    print('-' * 70)

    clients = {}
    history = []

    for round in range(ROUNDS):
        # Update the server state with the next iteration
        noise_list = [noise for _ in range(num_clients)]
        # noise_federated = tff.federated_value(noise_list, tff.CLIENTS)
        res = noisy_federated_algorithm.next(server_state, federated_data, noise)
        server_state, client_weights = res
        clients[round] = client_weights

        # Evaluate the performance after each round
        loss, accuracy, f1_score_value = evaluate(server_state)
        history.append([loss, accuracy, f1_score_value])

        print(f'Round: {round}')
        print(f"\nTest Loss: {loss:.4f}")
        print(f"Test Accuracy: {accuracy :.4f}")
        print(f"Test F1 Score: {f1_score_value:.4f}")
        print(f"Noise Value: {noise}")
        print('.' * 70)

    return clients, server_state, history

# %%
# List of noise values to test
step_size =2
noise_values = np.arange(2, 11, step_size).tolist()

# noise_values = [0.5, 0.9, 1.5, 2.7, 3.9]
N_history_per_noise = {}
noisy_clients_weights = {}
noisy_server_weights = {}
for noise_value in noise_values:
    clients, final_server_state, history = run_noisy_federated_algorithm(noise_value,federated_data,ROUNDS)
    N_history_per_noise[noise_value] = history
    noisy_clients_weights[noise_value] = clients
    noisy_server_weights[noise_value] = final_server_state
# Out:
# 2024-02-29 18:46:38.638598: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:46:38.638686: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# Initial Loss: 0.5670504570007324, Accuracy: 0.9914204478263855, F1 Score: 0.9937466382980347
# ----------------------------------------------------------------------
# 2024-02-29 18:47:15.397580: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.397647: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.483880: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.483959: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.488873: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.488932: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.494237: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.494320: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.499104: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.499149: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.507085: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.507141: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.516317: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.516361: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.524694: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.524743: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-29 18:47:15.546911: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-29 18:47:15.546977: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# Round: 0
#
# Test Loss: 0.4975
# Test Accuracy: 0.9841
# Test F1 Score: 0.9884
# Noise Value: 2
# ......................................................................
# Round: 1
#
# Test Loss: 0.4733
# Test Accuracy: 0.9779
# Test F1 Score: 0.9840
# Noise Value: 2
# ......................................................................
# Round: 2
#
# Test Loss: 0.4640
# Test Accuracy: 0.9725
# Test F1 Score: 0.9802
# Noise Value: 2
# ......................................................................
# Round: 3
#
# Test Loss: 0.4531
# Test Accuracy: 0.9675
# Test F1 Score: 0.9767
# Noise Value: 2
# ......................................................................
# Round: 4
#
# Test Loss: 0.4472
# Test Accuracy: 0.9628
# Test F1 Score: 0.9735
# Noise Value: 2
# ......................................................................
# Round: 5
#
# Test Loss: 0.4476
# Test Accuracy: 0.9584
# Test F1 Score: 0.9705
# Noise Value: 2
# ......................................................................
# Round: 6
#
# Test Loss: 0.4403
# Test Accuracy: 0.9543
# Test F1 Score: 0.9677
# Noise Value: 2
# ......................................................................
# Round: 7
#
# Test Loss: 0.4397
# Test Accuracy: 0.9504
# Test F1 Score: 0.9651
# Noise Value: 2
# ......................................................................
# Round: 8
#
# Test Loss: 0.4364
# Test Accuracy: 0.9467
# Test F1 Score: 0.9626
# Noise Value: 2
# ......................................................................
# Round: 9
#
# Test Loss: 0.4345
# Test Accuracy: 0.9432
# Test F1 Score: 0.9603
# Noise Value: 2
# ......................................................................
# Round: 10
#
# Test Loss: 0.4353
# Test Accuracy: 0.9400
# Test F1 Score: 0.9581
# Noise Value: 2
# ......................................................................
# Round: 11
#
# Test Loss: 0.4403
# Test Accuracy: 0.9368
# Test F1 Score: 0.9560
# Noise Value: 2
# ......................................................................
# Round: 12
#
# Test Loss: 0.4361
# Test Accuracy: 0.9337
# Test F1 Score: 0.9540
# Noise Value: 2
# ......................................................................
# Round: 13
#
# Test Loss: 0.4341
# Test Accuracy: 0.9308
# Test F1 Score: 0.9521
# Noise Value: 2
# ......................................................................
# Round: 14
#
# Test Loss: 0.4315
# Test Accuracy: 0.9281
# Test F1 Score: 0.9503
# Noise Value: 2
# ......................................................................
# Round: 15
#
# Test Loss: 0.4338
# Test Accuracy: 0.9253
# Test F1 Score: 0.9485
# Noise Value: 2
# ......................................................................
# Round: 16
#
# Test Loss: 0.4291
# Test Accuracy: 0.9227
# Test F1 Score: 0.9468
# Noise Value: 2
# ......................................................................
# Round: 17
#
# Test Loss: 0.4268
# Test Accuracy: 0.9204
# Test F1 Score: 0.9453
# Noise Value: 2
# ......................................................................
# Round: 18
#
# Test Loss: 0.4270
# Test Accuracy: 0.9182
# Test F1 Score: 0.9438
# Noise Value: 2
# ......................................................................
# Round: 19
#
# Test Loss: 0.4284
# Test Accuracy: 0.9159
# Test F1 Score: 0.9424
# Noise Value: 2
# ......................................................................
# Round: 20
#
# Test Loss: 0.4266
# Test Accuracy: 0.9140
# Test F1 Score: 0.9412
# Noise Value: 2
# ......................................................................
# Round: 21
#
# Test Loss: 0.4267
# Test Accuracy: 0.9119
# Test F1 Score: 0.9398
# Noise Value: 2
# ......................................................................
# Round: 22
#
# Test Loss: 0.4302
# Test Accuracy: 0.9099
# Test F1 Score: 0.9385
# Noise Value: 2
# ......................................................................
# Round: 23
#
# Test Loss: 0.4293
# Test Accuracy: 0.9080
# Test F1 Score: 0.9373
# Noise Value: 2
# ......................................................................
# Round: 24
#
# Test Loss: 0.4264
# Test Accuracy: 0.9062
# Test F1 Score: 0.9362
# Noise Value: 2
# ......................................................................
# Round: 25
#
# Test Loss: 0.4299
# Test Accuracy: 0.9045
# Test F1 Score: 0.9351
# Noise Value: 2
# ......................................................................
# Round: 26
#
# Test Loss: 0.4277
# Test Accuracy: 0.9028
# Test F1 Score: 0.9340
# Noise Value: 2
# ......................................................................
# Round: 27
#
# Test Loss: 0.4287
# Test Accuracy: 0.9013
# Test F1 Score: 0.9331
# Noise Value: 2
# ......................................................................
# Round: 28
#
# Test Loss: 0.4321
# Test Accuracy: 0.8997
# Test F1 Score: 0.9321
# Noise Value: 2
# ......................................................................
# Round: 29
#
# Test Loss: 0.4327
# Test Accuracy: 0.8982
# Test F1 Score: 0.9312
# Noise Value: 2
# ......................................................................
# Initial Loss: 0.5670504570007324, Accuracy: 0.8956668972969055, F1 Score: 0.9294904470443726
# ----------------------------------------------------------------------
# Round: 0
#
# Test Loss: 0.5553
# Test Accuracy: 0.8957
# Test F1 Score: 0.9278
# Noise Value: 4
# ......................................................................
# Round: 1
#
# Test Loss: 0.5237
# Test Accuracy: 0.8957
# Test F1 Score: 0.9260
# Noise Value: 4
# ......................................................................
# Round: 2
#
# Test Loss: 0.5229
# Test Accuracy: 0.8958
# Test F1 Score: 0.9244
# Noise Value: 4
# ......................................................................
# Round: 3
#
# Test Loss: 0.5240
# Test Accuracy: 0.8958
# Test F1 Score: 0.9227
# Noise Value: 4
# ......................................................................
# Round: 4
#
# Test Loss: 0.5280
# Test Accuracy: 0.8957
# Test F1 Score: 0.9209
# Noise Value: 4
# ......................................................................
# Round: 5
#
# Test Loss: 0.5226
# Test Accuracy: 0.8953
# Test F1 Score: 0.9192
# Noise Value: 4
# ......................................................................
# Round: 6
#
# Test Loss: 0.5269
# Test Accuracy: 0.8951
# Test F1 Score: 0.9174
# Noise Value: 4
# ......................................................................
# Round: 7
#
# Test Loss: 0.5457
# Test Accuracy: 0.8949
# Test F1 Score: 0.9159
# Noise Value: 4
# ......................................................................
# Round: 8
#
# Test Loss: 0.5306
# Test Accuracy: 0.8946
# Test F1 Score: 0.9143
# Noise Value: 4
# ......................................................................
# Round: 9
#
# Test Loss: 0.5383
# Test Accuracy: 0.8946
# Test F1 Score: 0.9127
# Noise Value: 4
# ......................................................................
# Round: 10
#
# Test Loss: 0.5383
# Test Accuracy: 0.8950
# Test F1 Score: 0.9113
# Noise Value: 4
# ......................................................................
# Round: 11
#
# Test Loss: 0.5391
# Test Accuracy: 0.8952
# Test F1 Score: 0.9098
# Noise Value: 4
# ......................................................................
# Round: 12
#
# Test Loss: 0.5264
# Test Accuracy: 0.8955
# Test F1 Score: 0.9085
# Noise Value: 4
# ......................................................................
# Round: 13
#
# Test Loss: 0.5171
# Test Accuracy: 0.8958
# Test F1 Score: 0.9072
# Noise Value: 4
# ......................................................................
# Round: 14
#
# Test Loss: 0.5219
# Test Accuracy: 0.8960
# Test F1 Score: 0.9059
# Noise Value: 4
# ......................................................................
# Round: 15
#
# Test Loss: 0.5375
# Test Accuracy: 0.8962
# Test F1 Score: 0.9046
# Noise Value: 4
# ......................................................................
# Round: 16
#
# Test Loss: 0.5405
# Test Accuracy: 0.8964
# Test F1 Score: 0.9033
# Noise Value: 4
# ......................................................................
# Round: 17
#
# Test Loss: 0.5417
# Test Accuracy: 0.8966
# Test F1 Score: 0.9021
# Noise Value: 4
# ......................................................................
# Round: 18
#
# Test Loss: 0.5367
# Test Accuracy: 0.8968
# Test F1 Score: 0.9010
# Noise Value: 4
# ......................................................................
# Round: 19
#
# Test Loss: 0.5426
# Test Accuracy: 0.8972
# Test F1 Score: 0.8999
# Noise Value: 4
# ......................................................................
# Round: 20
#
# Test Loss: 0.5445
# Test Accuracy: 0.8977
# Test F1 Score: 0.8990
# Noise Value: 4
# ......................................................................
# Round: 21
#
# Test Loss: 0.5400
# Test Accuracy: 0.8981
# Test F1 Score: 0.8981
# Noise Value: 4
# ......................................................................
# Round: 22
#
# Test Loss: 0.5410
# Test Accuracy: 0.8983
# Test F1 Score: 0.8970
# Noise Value: 4
# ......................................................................
# Round: 23
#
# Test Loss: 0.5596
# Test Accuracy: 0.8988
# Test F1 Score: 0.8961
# Noise Value: 4
# ......................................................................
# Round: 24
#
# Test Loss: 0.5587
# Test Accuracy: 0.8992
# Test F1 Score: 0.8952
# Noise Value: 4
# ......................................................................
# Round: 25
#
# Test Loss: 0.5605
# Test Accuracy: 0.8994
# Test F1 Score: 0.8942
# Noise Value: 4
# ......................................................................
# Round: 26
#
# Test Loss: 0.5488
# Test Accuracy: 0.8997
# Test F1 Score: 0.8933
# Noise Value: 4
# ......................................................................
# Round: 27
#
# Test Loss: 0.5471
# Test Accuracy: 0.9001
# Test F1 Score: 0.8925
# Noise Value: 4
# ......................................................................
# Round: 28
#
# Test Loss: 0.5328
# Test Accuracy: 0.9006
# Test F1 Score: 0.8918
# Noise Value: 4
# ......................................................................
# Round: 29
#
# Test Loss: 0.5500
# Test Accuracy: 0.9009
# Test F1 Score: 0.8910
# Noise Value: 4
# ......................................................................
# Initial Loss: 0.5670504570007324, Accuracy: 0.9014816284179688, F1 Score: 0.8904535174369812
# ----------------------------------------------------------------------
# Round: 0
#
# Test Loss: 0.6348
# Test Accuracy: 0.9005
# Test F1 Score: 0.8887
# Noise Value: 6
# ......................................................................
# Round: 1
#
# Test Loss: 0.5706
# Test Accuracy: 0.9012
# Test F1 Score: 0.8884
# Noise Value: 6
# ......................................................................
# Round: 2
#
# Test Loss: 0.5573
# Test Accuracy: 0.9018
# Test F1 Score: 0.8879
# Noise Value: 6
# ......................................................................
# Round: 3
#
# Test Loss: 0.5232
# Test Accuracy: 0.9021
# Test F1 Score: 0.8873
# Noise Value: 6
# ......................................................................
# Round: 4
#
# Test Loss: 0.5066
# Test Accuracy: 0.9025
# Test F1 Score: 0.8867
# Noise Value: 6
# ......................................................................
# Round: 5
#
# Test Loss: 0.5180
# Test Accuracy: 0.9029
# Test F1 Score: 0.8861
# Noise Value: 6
# ......................................................................
# Round: 6
#
# Test Loss: 0.5286
# Test Accuracy: 0.9029
# Test F1 Score: 0.8854
# Noise Value: 6
# ......................................................................
# Round: 7
#
# Test Loss: 0.5427
# Test Accuracy: 0.9030
# Test F1 Score: 0.8846
# Noise Value: 6
# ......................................................................
# Round: 8
#
# Test Loss: 0.5730
# Test Accuracy: 0.9029
# Test F1 Score: 0.8838
# Noise Value: 6
# ......................................................................
# Round: 9
#
# Test Loss: 0.5881
# Test Accuracy: 0.9030
# Test F1 Score: 0.8832
# Noise Value: 6
# ......................................................................
# Round: 10
#
# Test Loss: 0.5947
# Test Accuracy: 0.9029
# Test F1 Score: 0.8824
# Noise Value: 6
# ......................................................................
# Round: 11
#
# Test Loss: 0.5825
# Test Accuracy: 0.9029
# Test F1 Score: 0.8817
# Noise Value: 6
# ......................................................................
# Round: 12
#
# Test Loss: 0.5710
# Test Accuracy: 0.9030
# Test F1 Score: 0.8811
# Noise Value: 6
# ......................................................................
# Round: 13
#
# Test Loss: 0.5555
# Test Accuracy: 0.9031
# Test F1 Score: 0.8804
# Noise Value: 6
# ......................................................................
# Round: 14
#
# Test Loss: 0.5392
# Test Accuracy: 0.9032
# Test F1 Score: 0.8799
# Noise Value: 6
# ......................................................................
# Round: 15
#
# Test Loss: 0.5934
# Test Accuracy: 0.9033
# Test F1 Score: 0.8793
# Noise Value: 6
# ......................................................................
# Round: 16
#
# Test Loss: 0.6218
# Test Accuracy: 0.9032
# Test F1 Score: 0.8786
# Noise Value: 6
# ......................................................................
# Round: 17
#
# Test Loss: 0.6600
# Test Accuracy: 0.9035
# Test F1 Score: 0.8781
# Noise Value: 6
# ......................................................................
# Round: 18
#
# Test Loss: 0.6311
# Test Accuracy: 0.9035
# Test F1 Score: 0.8775
# Noise Value: 6
# ......................................................................
# Round: 19
#
# Test Loss: 0.5893
# Test Accuracy: 0.9033
# Test F1 Score: 0.8769
# Noise Value: 6
# ......................................................................
# Round: 20
#
# Test Loss: 0.6472
# Test Accuracy: 0.9031
# Test F1 Score: 0.8761
# Noise Value: 6
# ......................................................................
# Round: 21
#
# Test Loss: 0.6415
# Test Accuracy: 0.9027
# Test F1 Score: 0.8753
# Noise Value: 6
# ......................................................................
# Round: 22
#
# Test Loss: 0.6485
# Test Accuracy: 0.9025
# Test F1 Score: 0.8745
# Noise Value: 6
# ......................................................................
# Round: 23
#
# Test Loss: 0.6292
# Test Accuracy: 0.9024
# Test F1 Score: 0.8739
# Noise Value: 6
# ......................................................................
# Round: 24
#
# Test Loss: 0.6788
# Test Accuracy: 0.9017
# Test F1 Score: 0.8729
# Noise Value: 6
# ......................................................................
# Round: 25
#
# Test Loss: 0.7001
# Test Accuracy: 0.9001
# Test F1 Score: 0.8715
# Noise Value: 6
# ......................................................................
# Round: 26
#
# Test Loss: 0.7454
# Test Accuracy: 0.8966
# Test F1 Score: 0.8687
# Noise Value: 6
# ......................................................................
# Round: 27
#
# Test Loss: 0.7914
# Test Accuracy: 0.8926
# Test F1 Score: 0.8655
# Noise Value: 6
# ......................................................................
# Round: 28
#
# Test Loss: 0.8347
# Test Accuracy: 0.8879
# Test F1 Score: 0.8619
# Noise Value: 6
# ......................................................................
# Round: 29
#
# Test Loss: 0.7469
# Test Accuracy: 0.8851
# Test F1 Score: 0.8598
# Noise Value: 6
# ......................................................................
# Initial Loss: 0.5670504570007324, Accuracy: 0.8856728672981262, F1 Score: 0.8596042990684509
# ----------------------------------------------------------------------
# Round: 0
#
# Test Loss: 0.5508
# Test Accuracy: 0.8861
# Test F1 Score: 0.8594
# Noise Value: 8
# ......................................................................
# Round: 1
#
# Test Loss: 0.5519
# Test Accuracy: 0.8865
# Test F1 Score: 0.8592
# Noise Value: 8
# ......................................................................
# Round: 2
#
# Test Loss: 0.5354
# Test Accuracy: 0.8869
# Test F1 Score: 0.8589
# Noise Value: 8
# ......................................................................
# Round: 3
#
# Test Loss: 0.5547
# Test Accuracy: 0.8875
# Test F1 Score: 0.8588
# Noise Value: 8
# ......................................................................
# Round: 4
#
# Test Loss: 0.5645
# Test Accuracy: 0.8876
# Test F1 Score: 0.8585
# Noise Value: 8
# ......................................................................
# Round: 5
#
# Test Loss: 0.5759
# Test Accuracy: 0.8879
# Test F1 Score: 0.8582
# Noise Value: 8
# ......................................................................
# Round: 6
#
# Test Loss: 0.5664
# Test Accuracy: 0.8880
# Test F1 Score: 0.8579
# Noise Value: 8
# ......................................................................
# Round: 7
#
# Test Loss: 0.5749
# Test Accuracy: 0.8882
# Test F1 Score: 0.8576
# Noise Value: 8
# ......................................................................
# Round: 8
#
# Test Loss: 0.6153
# Test Accuracy: 0.8883
# Test F1 Score: 0.8573
# Noise Value: 8
# ......................................................................
# Round: 9
#
# Test Loss: 0.6097
# Test Accuracy: 0.8884
# Test F1 Score: 0.8570
# Noise Value: 8
# ......................................................................
# Round: 10
#
# Test Loss: 0.6534
# Test Accuracy: 0.8887
# Test F1 Score: 0.8567
# Noise Value: 8
# ......................................................................
# Round: 11
#
# Test Loss: 0.6119
# Test Accuracy: 0.8889
# Test F1 Score: 0.8565
# Noise Value: 8
# ......................................................................
# Round: 12
#
# Test Loss: 0.6394
# Test Accuracy: 0.8889
# Test F1 Score: 0.8561
# Noise Value: 8
# ......................................................................
# Round: 13
#
# Test Loss: 0.6706
# Test Accuracy: 0.8891
# Test F1 Score: 0.8558
# Noise Value: 8
# ......................................................................
# Round: 14
#
# Test Loss: 0.6022
# Test Accuracy: 0.8893
# Test F1 Score: 0.8556
# Noise Value: 8
# ......................................................................
# Round: 15
#
# Test Loss: 0.6548
# Test Accuracy: 0.8896
# Test F1 Score: 0.8553
# Noise Value: 8
# ......................................................................
# Round: 16
#
# Test Loss: 0.5718
# Test Accuracy: 0.8899
# Test F1 Score: 0.8552
# Noise Value: 8
# ......................................................................
# Round: 17
#
# Test Loss: 0.5920
# Test Accuracy: 0.8901
# Test F1 Score: 0.8549
# Noise Value: 8
# ......................................................................
# Round: 18
#
# Test Loss: 0.5477
# Test Accuracy: 0.8905
# Test F1 Score: 0.8548
# Noise Value: 8
# ......................................................................
# Round: 19
#
# Test Loss: 0.5850
# Test Accuracy: 0.8911
# Test F1 Score: 0.8548
# Noise Value: 8
# ......................................................................
# Round: 20
#
# Test Loss: 0.5114
# Test Accuracy: 0.8917
# Test F1 Score: 0.8549
# Noise Value: 8
# ......................................................................
# Round: 21
#
# Test Loss: 0.5656
# Test Accuracy: 0.8922
# Test F1 Score: 0.8548
# Noise Value: 8
# ......................................................................
# Round: 22
#
# Test Loss: 0.4731
# Test Accuracy: 0.8926
# Test F1 Score: 0.8548
# Noise Value: 8
# ......................................................................
# Round: 23
#
# Test Loss: 0.5063
# Test Accuracy: 0.8929
# Test F1 Score: 0.8546
# Noise Value: 8
# ......................................................................
# Round: 24
#
# Test Loss: 0.5251
# Test Accuracy: 0.8932
# Test F1 Score: 0.8545
# Noise Value: 8
# ......................................................................
# Round: 25
#
# Test Loss: 0.5667
# Test Accuracy: 0.8933
# Test F1 Score: 0.8542
# Noise Value: 8
# ......................................................................
# Round: 26
#
# Test Loss: 0.5519
# Test Accuracy: 0.8934
# Test F1 Score: 0.8540
# Noise Value: 8
# ......................................................................
# Round: 27
#
# Test Loss: 0.5470
# Test Accuracy: 0.8936
# Test F1 Score: 0.8538
# Noise Value: 8
# ......................................................................
# Round: 28
#
# Test Loss: 0.5567
# Test Accuracy: 0.8937
# Test F1 Score: 0.8536
# Noise Value: 8
# ......................................................................
# Round: 29
#
# Test Loss: 0.5808
# Test Accuracy: 0.8939
# Test F1 Score: 0.8533
# Noise Value: 8
# ......................................................................
# Initial Loss: 0.5670504570007324, Accuracy: 0.8942403197288513, F1 Score: 0.8532559871673584
# ----------------------------------------------------------------------
# Round: 0
#
# Test Loss: 0.5741
# Test Accuracy: 0.8946
# Test F1 Score: 0.8532
# Noise Value: 10
# ......................................................................
# Round: 1
#
# Test Loss: 0.5644
# Test Accuracy: 0.8950
# Test F1 Score: 0.8531
# Noise Value: 10
# ......................................................................
# Round: 2
#
# Test Loss: 0.5413
# Test Accuracy: 0.8955
# Test F1 Score: 0.8531
# Noise Value: 10
# ......................................................................
# Round: 3
#
# Test Loss: 0.5221
# Test Accuracy: 0.8961
# Test F1 Score: 0.8532
# Noise Value: 10
# ......................................................................
# Round: 4
#
# Test Loss: 0.5194
# Test Accuracy: 0.8967
# Test F1 Score: 0.8534
# Noise Value: 10
# ......................................................................
# Round: 5
#
# Test Loss: 0.5937
# Test Accuracy: 0.8973
# Test F1 Score: 0.8533
# Noise Value: 10
# ......................................................................
# Round: 6
#
# Test Loss: 0.6276
# Test Accuracy: 0.8977
# Test F1 Score: 0.8526
# Noise Value: 10
# ......................................................................
# Round: 7
#
# Test Loss: 0.5004
# Test Accuracy: 0.8983
# Test F1 Score: 0.8526
# Noise Value: 10
# ......................................................................
# Round: 8
#
# Test Loss: 0.5955
# Test Accuracy: 0.8988
# Test F1 Score: 0.8525
# Noise Value: 10
# ......................................................................
# Round: 9
#
# Test Loss: 0.6458
# Test Accuracy: 0.8994
# Test F1 Score: 0.8524
# Noise Value: 10
# ......................................................................
# Round: 10
#
# Test Loss: 0.5291
# Test Accuracy: 0.8999
# Test F1 Score: 0.8525
# Noise Value: 10
# ......................................................................
# Round: 11
#
# Test Loss: 0.6171
# Test Accuracy: 0.9005
# Test F1 Score: 0.8521
# Noise Value: 10
# ......................................................................
# Round: 12
#
# Test Loss: 0.5058
# Test Accuracy: 0.9010
# Test F1 Score: 0.8522
# Noise Value: 10
# ......................................................................
# Round: 13
#
# Test Loss: 0.4876
# Test Accuracy: 0.9016
# Test F1 Score: 0.8522
# Noise Value: 10
# ......................................................................
# Round: 14
#
# Test Loss: 0.4937
# Test Accuracy: 0.9021
# Test F1 Score: 0.8523
# Noise Value: 10
# ......................................................................
# Round: 15
#
# Test Loss: 0.6200
# Test Accuracy: 0.9026
# Test F1 Score: 0.8524
# Noise Value: 10
# ......................................................................
# Round: 16
#
# Test Loss: 0.7118
# Test Accuracy: 0.9031
# Test F1 Score: 0.8522
# Noise Value: 10
# ......................................................................
# Round: 17
#
# Test Loss: 0.6759
# Test Accuracy: 0.9036
# Test F1 Score: 0.8520
# Noise Value: 10
# ......................................................................
# Round: 18
#
# Test Loss: 0.5947
# Test Accuracy: 0.9041
# Test F1 Score: 0.8519
# Noise Value: 10
# ......................................................................
# Round: 19
#
# Test Loss: 0.6243
# Test Accuracy: 0.9046
# Test F1 Score: 0.8517
# Noise Value: 10
# ......................................................................
# Round: 20
#
# Test Loss: 0.6096
# Test Accuracy: 0.9051
# Test F1 Score: 0.8515
# Noise Value: 10
# ......................................................................
# Round: 21
#
# Test Loss: 0.6618
# Test Accuracy: 0.9056
# Test F1 Score: 0.8512
# Noise Value: 10
# ......................................................................
# Round: 22
#
# Test Loss: 0.6496
# Test Accuracy: 0.9061
# Test F1 Score: 0.8510
# Noise Value: 10
# ......................................................................
# Round: 23
#
# Test Loss: 0.7099
# Test Accuracy: 0.9065
# Test F1 Score: 0.8509
# Noise Value: 10
# ......................................................................
# Round: 24
#
# Test Loss: 0.7286
# Test Accuracy: 0.9070
# Test F1 Score: 0.8509
# Noise Value: 10
# ......................................................................
# Round: 25
#
# Test Loss: 0.6630
# Test Accuracy: 0.9075
# Test F1 Score: 0.8507
# Noise Value: 10
# ......................................................................
# Round: 26
#
# Test Loss: 0.6150
# Test Accuracy: 0.9079
# Test F1 Score: 0.8508
# Noise Value: 10
# ......................................................................
# Round: 27
#
# Test Loss: 0.6391
# Test Accuracy: 0.9084
# Test F1 Score: 0.8506
# Noise Value: 10
# ......................................................................
# Round: 28
#
# Test Loss: 0.7746
# Test Accuracy: 0.9087
# Test F1 Score: 0.8499
# Noise Value: 10
# ......................................................................
# Round: 29
#
# Test Loss: 0.6152
# Test Accuracy: 0.9091
# Test F1 Score: 0.8498
# Noise Value: 10
# ......................................................................

# %%
import tensorflow_privacy as tfp

results_per_noise = {}
delta = 1e-2

for round_num in range(ROUNDS):
    print(f"\nRound: {round_num + 1}")
    
    for noise_multiplier in noise_values:
        print(f"Noise Multiplier: {noise_multiplier}")
        
        n_client_epsilons = []
        n_client_renyi = []

        for i, dataset in enumerate(federated_data):
            epsilon, rdp = tfp.compute_dp_sgd_privacy(
                dataset.__len__().numpy(),
                BATCH_SIZE,
                noise_multiplier,
                round_num + 1,
                1e-2,
            )
            n_client_epsilons.append(epsilon)
            n_client_renyi.append(rdp)

        avg_epsilon = sum(n_client_epsilons) / len(n_client_epsilons)
        avg_rdp = sum(n_client_renyi) / len(n_client_renyi)

        print(f"    Average Epsilon = {avg_epsilon}, Average RDP = {avg_rdp}")

        results_per_noise[(noise_multiplier, round_num)] = {
            'avg_epsilon': avg_epsilon,
            'avg_rdp': avg_rdp
        }

# Debugging prints
for key, value in results_per_noise.items():
    print(f"\nNoise Multiplier: {key[0]}, Round: {key[1]}")
    print(f"    Average Epsilon = {value['avg_epsilon']}, Average RDP = {value['avg_rdp']}")
# Out:
# Round: 1
# Noise Multiplier: 2
#     Average Epsilon = 0.0033842863984271643, Average RDP = 52.57142857142857
# Noise Multiplier: 4
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 6
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 128.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 128.0
#
# Round: 2
# Noise Multiplier: 2
#     Average Epsilon = 0.01202725723168247, Average RDP = 47.285714285714285
# Noise Multiplier: 4
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 6
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 128.0
#
# Round: 3
# Noise Multiplier: 2
#     Average Epsilon = 0.019923687060029217, Average RDP = 42.0
# Noise Multiplier: 4
#     Average Epsilon = 0.000821051004079597, Average RDP = 60.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
#
# Round: 4
# Noise Multiplier: 2
#     Average Epsilon = 0.027006051445916546, Average RDP = 38.285714285714285
# Noise Multiplier: 4
#     Average Epsilon = 0.002536035448125532, Average RDP = 58.0
# Noise Multiplier: 6
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
#
# Round: 5
# Noise Multiplier: 2
#     Average Epsilon = 0.03352644696499086, Average RDP = 35.714285714285715
# Noise Multiplier: 4
#     Average Epsilon = 0.0042758861261642175, Average RDP = 55.57142857142857
# Noise Multiplier: 6
#     Average Epsilon = 0.0, Average RDP = 62.857142857142854
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
#
# Round: 6
# Noise Multiplier: 2
#     Average Epsilon = 0.039624699374094595, Average RDP = 33.57142857142857
# Noise Multiplier: 4
#     Average Epsilon = 0.006272980320556893, Average RDP = 53.0
# Noise Multiplier: 6
#     Average Epsilon = 0.00021713034932682802, Average RDP = 61.714285714285715
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
#
# Round: 7
# Noise Multiplier: 2
#     Average Epsilon = 0.04539290734903408, Average RDP = 31.714285714285715
# Noise Multiplier: 4
#     Average Epsilon = 0.008219097775764612, Average RDP = 51.0
# Noise Multiplier: 6
#     Average Epsilon = 0.0009026432027999109, Average RDP = 60.285714285714285
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 8
# Noise Multiplier: 2
#     Average Epsilon = 0.05086803904771569, Average RDP = 30.428571428571427
# Noise Multiplier: 4
#     Average Epsilon = 0.010215992712430693, Average RDP = 49.142857142857146
# Noise Multiplier: 6
#     Average Epsilon = 0.0016631665930867021, Average RDP = 59.142857142857146
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 63.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 9
# Noise Multiplier: 2
#     Average Epsilon = 0.05611951784115381, Average RDP = 29.285714285714285
# Noise Multiplier: 4
#     Average Epsilon = 0.012140236076282564, Average RDP = 47.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.0023995662951161963, Average RDP = 58.285714285714285
# Noise Multiplier: 8
#     Average Epsilon = 0.0, Average RDP = 62.857142857142854
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 10
# Noise Multiplier: 2
#     Average Epsilon = 0.06116605665344239, Average RDP = 28.142857142857142
# Noise Multiplier: 4
#     Average Epsilon = 0.014001115239108864, Average RDP = 45.857142857142854
# Noise Multiplier: 6
#     Average Epsilon = 0.0031127157695418216, Average RDP = 57.285714285714285
# Noise Multiplier: 8
#     Average Epsilon = 5.5441347757866225e-05, Average RDP = 62.285714285714285
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 11
# Noise Multiplier: 2
#     Average Epsilon = 0.06604810279338037, Average RDP = 27.142857142857142
# Noise Multiplier: 4
#     Average Epsilon = 0.015806018236592577, Average RDP = 44.57142857142857
# Noise Multiplier: 6
#     Average Epsilon = 0.0038541878243126175, Average RDP = 56.0
# Noise Multiplier: 8
#     Average Epsilon = 0.00030486628198546237, Average RDP = 61.42857142857143
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 12
# Noise Multiplier: 2
#     Average Epsilon = 0.07077892326316407, Average RDP = 26.285714285714285
# Noise Multiplier: 4
#     Average Epsilon = 0.017561155332420603, Average RDP = 43.57142857142857
# Noise Multiplier: 6
#     Average Epsilon = 0.004737127792841107, Average RDP = 54.714285714285715
# Noise Multiplier: 8
#     Average Epsilon = 0.0006692810789369589, Average RDP = 60.857142857142854
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 13
# Noise Multiplier: 2
#     Average Epsilon = 0.07534690052851388, Average RDP = 25.857142857142858
# Noise Multiplier: 4
#     Average Epsilon = 0.019271751078005456, Average RDP = 42.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.005609348117413391, Average RDP = 53.857142857142854
# Noise Multiplier: 8
#     Average Epsilon = 0.0011024510111212256, Average RDP = 60.285714285714285
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Round: 14
# Noise Multiplier: 2
#     Average Epsilon = 0.07981295805231693, Average RDP = 25.0
# Noise Multiplier: 4
#     Average Epsilon = 0.020941163311645947, Average RDP = 41.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.006462968071578537, Average RDP = 53.0
# Noise Multiplier: 8
#     Average Epsilon = 0.0015267899029505494, Average RDP = 59.57142857142857
# Noise Multiplier: 10
#     Average Epsilon = 0.0, Average RDP = 62.857142857142854
#
# Round: 15
# Noise Multiplier: 2
#     Average Epsilon = 0.08415793285919286, Average RDP = 24.714285714285715
# Noise Multiplier: 4
#     Average Epsilon = 0.022574615764460786, Average RDP = 40.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.007299660656852729, Average RDP = 52.0
# Noise Multiplier: 8
#     Average Epsilon = 0.001943359304514013, Average RDP = 58.857142857142854
# Noise Multiplier: 10
#     Average Epsilon = 1.8469071576952326e-06, Average RDP = 62.57142857142857
#
# Round: 16
# Noise Multiplier: 2
#     Average Epsilon = 0.08839619717736427, Average RDP = 23.857142857142858
# Noise Multiplier: 4
#     Average Epsilon = 0.024171393854145573, Average RDP = 39.857142857142854
# Noise Multiplier: 6
#     Average Epsilon = 0.00815898878098059, Average RDP = 51.0
# Noise Multiplier: 8
#     Average Epsilon = 0.0023523232904941608, Average RDP = 58.42857142857143
# Noise Multiplier: 10
#     Average Epsilon = 8.03916325082941e-05, Average RDP = 62.142857142857146
#
# Round: 17
# Noise Multiplier: 2
#     Average Epsilon = 0.09254684440580303, Average RDP = 23.571428571428573
# Noise Multiplier: 4
#     Average Epsilon = 0.025735968264530912, Average RDP = 39.0
# Noise Multiplier: 6
#     Average Epsilon = 0.009040692079929828, Average RDP = 50.142857142857146
# Noise Multiplier: 8
#     Average Epsilon = 0.0027544832717356043, Average RDP = 58.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0002507995017403588, Average RDP = 61.57142857142857
#
# Round: 18
# Noise Multiplier: 2
#     Average Epsilon = 0.09660785578453927, Average RDP = 23.0
# Noise Multiplier: 4
#     Average Epsilon = 0.0272733924188874, Average RDP = 38.285714285714285
# Noise Multiplier: 6
#     Average Epsilon = 0.009907038817438776, Average RDP = 49.42857142857143
# Noise Multiplier: 8
#     Average Epsilon = 0.003150056980126384, Average RDP = 57.285714285714285
# Noise Multiplier: 10
#     Average Epsilon = 0.000469708403010016, Average RDP = 61.285714285714285
#
# Round: 19
# Noise Multiplier: 2
#     Average Epsilon = 0.10057721755448491, Average RDP = 22.571428571428573
# Noise Multiplier: 4
#     Average Epsilon = 0.028781471890886097, Average RDP = 37.857142857142854
# Noise Multiplier: 6
#     Average Epsilon = 0.010758520102382266, Average RDP = 48.57142857142857
# Noise Multiplier: 8
#     Average Epsilon = 0.0035425975073453647, Average RDP = 56.42857142857143
# Noise Multiplier: 10
#     Average Epsilon = 0.0007214156825628969, Average RDP = 60.857142857142854
#
# Round: 20
# Noise Multiplier: 2
#     Average Epsilon = 0.10449971970473369, Average RDP = 22.142857142857142
# Noise Multiplier: 4
#     Average Epsilon = 0.030262428865644377, Average RDP = 36.857142857142854
# Noise Multiplier: 6
#     Average Epsilon = 0.01159738886280123, Average RDP = 47.714285714285715
# Noise Multiplier: 8
#     Average Epsilon = 0.00399806483532631, Average RDP = 55.714285714285715
# Noise Multiplier: 10
#     Average Epsilon = 0.0009975471677959554, Average RDP = 60.285714285714285
#
# Round: 21
# Noise Multiplier: 2
#     Average Epsilon = 0.10832094745504928, Average RDP = 21.714285714285715
# Noise Multiplier: 4
#     Average Epsilon = 0.03172469756077735, Average RDP = 36.714285714285715
# Noise Multiplier: 6
#     Average Epsilon = 0.01242545466214297, Average RDP = 47.42857142857143
# Noise Multiplier: 8
#     Average Epsilon = 0.004498242954631783, Average RDP = 55.285714285714285
# Noise Multiplier: 10
#     Average Epsilon = 0.0012709865311512274, Average RDP = 59.714285714285715
#
# Round: 22
# Noise Multiplier: 2
#     Average Epsilon = 0.11208396596471264, Average RDP = 21.428571428571427
# Noise Multiplier: 4
#     Average Epsilon = 0.03315610625511932, Average RDP = 35.857142857142854
# Noise Multiplier: 6
#     Average Epsilon = 0.01323870372976203, Average RDP = 46.57142857142857
# Noise Multiplier: 8
#     Average Epsilon = 0.004990164051519991, Average RDP = 54.714285714285715
# Noise Multiplier: 10
#     Average Epsilon = 0.001540594065775192, Average RDP = 59.42857142857143
#
# Round: 23
# Noise Multiplier: 2
#     Average Epsilon = 0.11581359282592898, Average RDP = 20.857142857142858
# Noise Multiplier: 4
#     Average Epsilon = 0.03457468951819842, Average RDP = 35.57142857142857
# Noise Multiplier: 6
#     Average Epsilon = 0.014044152540595616, Average RDP = 45.857142857142854
# Noise Multiplier: 8
#     Average Epsilon = 0.005477548781001074, Average RDP = 54.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0018067348724933444, Average RDP = 59.142857142857146
#
# Round: 24
# Noise Multiplier: 2
#     Average Epsilon = 0.11943546129369444, Average RDP = 20.714285714285715
# Noise Multiplier: 4
#     Average Epsilon = 0.035965043994960776, Average RDP = 34.857142857142854
# Noise Multiplier: 6
#     Average Epsilon = 0.014836541963515025, Average RDP = 45.42857142857143
# Noise Multiplier: 8
#     Average Epsilon = 0.005958375612440307, Average RDP = 53.714285714285715
# Noise Multiplier: 10
#     Average Epsilon = 0.0020702273408533677, Average RDP = 58.57142857142857
#
# Round: 25
# Noise Multiplier: 2
#     Average Epsilon = 0.12302748891083748, Average RDP = 20.428571428571427
# Noise Multiplier: 4
#     Average Epsilon = 0.03733987959259897, Average RDP = 34.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.015620144119273946, Average RDP = 44.57142857142857
# Noise Multiplier: 8
#     Average Epsilon = 0.006432931877939135, Average RDP = 53.0
# Noise Multiplier: 10
#     Average Epsilon = 0.002330717929618515, Average RDP = 58.42857142857143
#
# Round: 26
# Noise Multiplier: 2
#     Average Epsilon = 0.12657901460530405, Average RDP = 20.142857142857142
# Noise Multiplier: 4
#     Average Epsilon = 0.038697721220861424, Average RDP = 34.0
# Noise Multiplier: 6
#     Average Epsilon = 0.01639342360234602, Average RDP = 44.285714285714285
# Noise Multiplier: 8
#     Average Epsilon = 0.006903583454721856, Average RDP = 52.285714285714285
# Noise Multiplier: 10
#     Average Epsilon = 0.0025879433924364953, Average RDP = 58.0
#
# Round: 27
# Noise Multiplier: 2
#     Average Epsilon = 0.1300710005941055, Average RDP = 19.857142857142858
# Noise Multiplier: 4
#     Average Epsilon = 0.04003252490568036, Average RDP = 33.57142857142857
# Noise Multiplier: 6
#     Average Epsilon = 0.017158694464318575, Average RDP = 43.57142857142857
# Noise Multiplier: 8
#     Average Epsilon = 0.007367496731165552, Average RDP = 52.0
# Noise Multiplier: 10
#     Average Epsilon = 0.0028433833929718626, Average RDP = 57.714285714285715
#
# Round: 28
# Noise Multiplier: 2
#     Average Epsilon = 0.13350068747932883, Average RDP = 19.714285714285715
# Noise Multiplier: 4
#     Average Epsilon = 0.041359143523364485, Average RDP = 33.285714285714285
# Noise Multiplier: 6
#     Average Epsilon = 0.017913599880259763, Average RDP = 43.285714285714285
# Noise Multiplier: 8
#     Average Epsilon = 0.007839481925807827, Average RDP = 51.285714285714285
# Noise Multiplier: 10
#     Average Epsilon = 0.003095118706617672, Average RDP = 57.285714285714285
#
# Round: 29
# Noise Multiplier: 2
#     Average Epsilon = 0.13690036262741842, Average RDP = 19.285714285714285
# Noise Multiplier: 4
#     Average Epsilon = 0.04266244125654859, Average RDP = 32.57142857142857
# Noise Multiplier: 6
#     Average Epsilon = 0.01866237455147359, Average RDP = 42.714285714285715
# Noise Multiplier: 8
#     Average Epsilon = 0.008336473137958078, Average RDP = 50.714285714285715
# Noise Multiplier: 10
#     Average Epsilon = 0.003345589334173306, Average RDP = 56.857142857142854
#
# Round: 30
# Noise Multiplier: 2
#     Average Epsilon = 0.1402483097577673, Average RDP = 19.142857142857142
# Noise Multiplier: 4
#     Average Epsilon = 0.04394941777368465, Average RDP = 32.42857142857143
# Noise Multiplier: 6
#     Average Epsilon = 0.019399704539841325, Average RDP = 42.42857142857143
# Noise Multiplier: 8
#     Average Epsilon = 0.008829319180630627, Average RDP = 50.42857142857143
# Noise Multiplier: 10
#     Average Epsilon = 0.003603990914793058, Average RDP = 56.42857142857143
#
# Noise Multiplier: 2, Round: 0
#     Average Epsilon = 0.0033842863984271643, Average RDP = 52.57142857142857
#
# Noise Multiplier: 4, Round: 0
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 6, Round: 0
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
#
# Noise Multiplier: 8, Round: 0
#     Average Epsilon = 0.0, Average RDP = 128.0
#
# Noise Multiplier: 10, Round: 0
#     Average Epsilon = 0.0, Average RDP = 128.0
#
# Noise Multiplier: 2, Round: 1
#     Average Epsilon = 0.01202725723168247, Average RDP = 47.285714285714285
#
# Noise Multiplier: 4, Round: 1
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 6, Round: 1
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
#
# Noise Multiplier: 8, Round: 1
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
#
# Noise Multiplier: 10, Round: 1
#     Average Epsilon = 0.0, Average RDP = 128.0
#
# Noise Multiplier: 2, Round: 2
#     Average Epsilon = 0.019923687060029217, Average RDP = 42.0
#
# Noise Multiplier: 4, Round: 2
#     Average Epsilon = 0.000821051004079597, Average RDP = 60.42857142857143
#
# Noise Multiplier: 6, Round: 2
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 8, Round: 2
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
#
# Noise Multiplier: 10, Round: 2
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
#
# Noise Multiplier: 2, Round: 3
#     Average Epsilon = 0.027006051445916546, Average RDP = 38.285714285714285
#
# Noise Multiplier: 4, Round: 3
#     Average Epsilon = 0.002536035448125532, Average RDP = 58.0
#
# Noise Multiplier: 6, Round: 3
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 8, Round: 3
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 10, Round: 3
#     Average Epsilon = 0.0, Average RDP = 90.85714285714286
#
# Noise Multiplier: 2, Round: 4
#     Average Epsilon = 0.03352644696499086, Average RDP = 35.714285714285715
#
# Noise Multiplier: 4, Round: 4
#     Average Epsilon = 0.0042758861261642175, Average RDP = 55.57142857142857
#
# Noise Multiplier: 6, Round: 4
#     Average Epsilon = 0.0, Average RDP = 62.857142857142854
#
# Noise Multiplier: 8, Round: 4
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 10, Round: 4
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
#
# Noise Multiplier: 2, Round: 5
#     Average Epsilon = 0.039624699374094595, Average RDP = 33.57142857142857
#
# Noise Multiplier: 4, Round: 5
#     Average Epsilon = 0.006272980320556893, Average RDP = 53.0
#
# Noise Multiplier: 6, Round: 5
#     Average Epsilon = 0.00021713034932682802, Average RDP = 61.714285714285715
#
# Noise Multiplier: 8, Round: 5
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 10, Round: 5
#     Average Epsilon = 0.0, Average RDP = 72.28571428571429
#
# Noise Multiplier: 2, Round: 6
#     Average Epsilon = 0.04539290734903408, Average RDP = 31.714285714285715
#
# Noise Multiplier: 4, Round: 6
#     Average Epsilon = 0.008219097775764612, Average RDP = 51.0
#
# Noise Multiplier: 6, Round: 6
#     Average Epsilon = 0.0009026432027999109, Average RDP = 60.285714285714285
#
# Noise Multiplier: 8, Round: 6
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 10, Round: 6
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 7
#     Average Epsilon = 0.05086803904771569, Average RDP = 30.428571428571427
#
# Noise Multiplier: 4, Round: 7
#     Average Epsilon = 0.010215992712430693, Average RDP = 49.142857142857146
#
# Noise Multiplier: 6, Round: 7
#     Average Epsilon = 0.0016631665930867021, Average RDP = 59.142857142857146
#
# Noise Multiplier: 8, Round: 7
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 10, Round: 7
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 8
#     Average Epsilon = 0.05611951784115381, Average RDP = 29.285714285714285
#
# Noise Multiplier: 4, Round: 8
#     Average Epsilon = 0.012140236076282564, Average RDP = 47.42857142857143
#
# Noise Multiplier: 6, Round: 8
#     Average Epsilon = 0.0023995662951161963, Average RDP = 58.285714285714285
#
# Noise Multiplier: 8, Round: 8
#     Average Epsilon = 0.0, Average RDP = 62.857142857142854
#
# Noise Multiplier: 10, Round: 8
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 9
#     Average Epsilon = 0.06116605665344239, Average RDP = 28.142857142857142
#
# Noise Multiplier: 4, Round: 9
#     Average Epsilon = 0.014001115239108864, Average RDP = 45.857142857142854
#
# Noise Multiplier: 6, Round: 9
#     Average Epsilon = 0.0031127157695418216, Average RDP = 57.285714285714285
#
# Noise Multiplier: 8, Round: 9
#     Average Epsilon = 5.5441347757866225e-05, Average RDP = 62.285714285714285
#
# Noise Multiplier: 10, Round: 9
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 10
#     Average Epsilon = 0.06604810279338037, Average RDP = 27.142857142857142
#
# Noise Multiplier: 4, Round: 10
#     Average Epsilon = 0.015806018236592577, Average RDP = 44.57142857142857
#
# Noise Multiplier: 6, Round: 10
#     Average Epsilon = 0.0038541878243126175, Average RDP = 56.0
#
# Noise Multiplier: 8, Round: 10
#     Average Epsilon = 0.00030486628198546237, Average RDP = 61.42857142857143
#
# Noise Multiplier: 10, Round: 10
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 11
#     Average Epsilon = 0.07077892326316407, Average RDP = 26.285714285714285
#
# Noise Multiplier: 4, Round: 11
#     Average Epsilon = 0.017561155332420603, Average RDP = 43.57142857142857
#
# Noise Multiplier: 6, Round: 11
#     Average Epsilon = 0.004737127792841107, Average RDP = 54.714285714285715
#
# Noise Multiplier: 8, Round: 11
#     Average Epsilon = 0.0006692810789369589, Average RDP = 60.857142857142854
#
# Noise Multiplier: 10, Round: 11
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 12
#     Average Epsilon = 0.07534690052851388, Average RDP = 25.857142857142858
#
# Noise Multiplier: 4, Round: 12
#     Average Epsilon = 0.019271751078005456, Average RDP = 42.42857142857143
#
# Noise Multiplier: 6, Round: 12
#     Average Epsilon = 0.005609348117413391, Average RDP = 53.857142857142854
#
# Noise Multiplier: 8, Round: 12
#     Average Epsilon = 0.0011024510111212256, Average RDP = 60.285714285714285
#
# Noise Multiplier: 10, Round: 12
#     Average Epsilon = 0.0, Average RDP = 63.0
#
# Noise Multiplier: 2, Round: 13
#     Average Epsilon = 0.07981295805231693, Average RDP = 25.0
#
# Noise Multiplier: 4, Round: 13
#     Average Epsilon = 0.020941163311645947, Average RDP = 41.42857142857143
#
# Noise Multiplier: 6, Round: 13
#     Average Epsilon = 0.006462968071578537, Average RDP = 53.0
#
# Noise Multiplier: 8, Round: 13
#     Average Epsilon = 0.0015267899029505494, Average RDP = 59.57142857142857
#
# Noise Multiplier: 10, Round: 13
#     Average Epsilon = 0.0, Average RDP = 62.857142857142854
#
# Noise Multiplier: 2, Round: 14
#     Average Epsilon = 0.08415793285919286, Average RDP = 24.714285714285715
#
# Noise Multiplier: 4, Round: 14
#     Average Epsilon = 0.022574615764460786, Average RDP = 40.42857142857143
#
# Noise Multiplier: 6, Round: 14
#     Average Epsilon = 0.007299660656852729, Average RDP = 52.0
#
# Noise Multiplier: 8, Round: 14
#     Average Epsilon = 0.001943359304514013, Average RDP = 58.857142857142854
#
# Noise Multiplier: 10, Round: 14
#     Average Epsilon = 1.8469071576952326e-06, Average RDP = 62.57142857142857
#
# Noise Multiplier: 2, Round: 15
#     Average Epsilon = 0.08839619717736427, Average RDP = 23.857142857142858
#
# Noise Multiplier: 4, Round: 15
#     Average Epsilon = 0.024171393854145573, Average RDP = 39.857142857142854
#
# Noise Multiplier: 6, Round: 15
#     Average Epsilon = 0.00815898878098059, Average RDP = 51.0
#
# Noise Multiplier: 8, Round: 15
#     Average Epsilon = 0.0023523232904941608, Average RDP = 58.42857142857143
#
# Noise Multiplier: 10, Round: 15
#     Average Epsilon = 8.03916325082941e-05, Average RDP = 62.142857142857146
#
# Noise Multiplier: 2, Round: 16
#     Average Epsilon = 0.09254684440580303, Average RDP = 23.571428571428573
#
# Noise Multiplier: 4, Round: 16
#     Average Epsilon = 0.025735968264530912, Average RDP = 39.0
#
# Noise Multiplier: 6, Round: 16
#     Average Epsilon = 0.009040692079929828, Average RDP = 50.142857142857146
#
# Noise Multiplier: 8, Round: 16
#     Average Epsilon = 0.0027544832717356043, Average RDP = 58.0
#
# Noise Multiplier: 10, Round: 16
#     Average Epsilon = 0.0002507995017403588, Average RDP = 61.57142857142857
#
# Noise Multiplier: 2, Round: 17
#     Average Epsilon = 0.09660785578453927, Average RDP = 23.0
#
# Noise Multiplier: 4, Round: 17
#     Average Epsilon = 0.0272733924188874, Average RDP = 38.285714285714285
#
# Noise Multiplier: 6, Round: 17
#     Average Epsilon = 0.009907038817438776, Average RDP = 49.42857142857143
#
# Noise Multiplier: 8, Round: 17
#     Average Epsilon = 0.003150056980126384, Average RDP = 57.285714285714285
#
# Noise Multiplier: 10, Round: 17
#     Average Epsilon = 0.000469708403010016, Average RDP = 61.285714285714285
#
# Noise Multiplier: 2, Round: 18
#     Average Epsilon = 0.10057721755448491, Average RDP = 22.571428571428573
#
# Noise Multiplier: 4, Round: 18
#     Average Epsilon = 0.028781471890886097, Average RDP = 37.857142857142854
#
# Noise Multiplier: 6, Round: 18
#     Average Epsilon = 0.010758520102382266, Average RDP = 48.57142857142857
#
# Noise Multiplier: 8, Round: 18
#     Average Epsilon = 0.0035425975073453647, Average RDP = 56.42857142857143
#
# Noise Multiplier: 10, Round: 18
#     Average Epsilon = 0.0007214156825628969, Average RDP = 60.857142857142854
#
# Noise Multiplier: 2, Round: 19
#     Average Epsilon = 0.10449971970473369, Average RDP = 22.142857142857142
#
# Noise Multiplier: 4, Round: 19
#     Average Epsilon = 0.030262428865644377, Average RDP = 36.857142857142854
#
# Noise Multiplier: 6, Round: 19
#     Average Epsilon = 0.01159738886280123, Average RDP = 47.714285714285715
#
# Noise Multiplier: 8, Round: 19
#     Average Epsilon = 0.00399806483532631, Average RDP = 55.714285714285715
#
# Noise Multiplier: 10, Round: 19
#     Average Epsilon = 0.0009975471677959554, Average RDP = 60.285714285714285
#
# Noise Multiplier: 2, Round: 20
#     Average Epsilon = 0.10832094745504928, Average RDP = 21.714285714285715
#
# Noise Multiplier: 4, Round: 20
#     Average Epsilon = 0.03172469756077735, Average RDP = 36.714285714285715
#
# Noise Multiplier: 6, Round: 20
#     Average Epsilon = 0.01242545466214297, Average RDP = 47.42857142857143
#
# Noise Multiplier: 8, Round: 20
#     Average Epsilon = 0.004498242954631783, Average RDP = 55.285714285714285
#
# Noise Multiplier: 10, Round: 20
#     Average Epsilon = 0.0012709865311512274, Average RDP = 59.714285714285715
#
# Noise Multiplier: 2, Round: 21
#     Average Epsilon = 0.11208396596471264, Average RDP = 21.428571428571427
#
# Noise Multiplier: 4, Round: 21
#     Average Epsilon = 0.03315610625511932, Average RDP = 35.857142857142854
#
# Noise Multiplier: 6, Round: 21
#     Average Epsilon = 0.01323870372976203, Average RDP = 46.57142857142857
#
# Noise Multiplier: 8, Round: 21
#     Average Epsilon = 0.004990164051519991, Average RDP = 54.714285714285715
#
# Noise Multiplier: 10, Round: 21
#     Average Epsilon = 0.001540594065775192, Average RDP = 59.42857142857143
#
# Noise Multiplier: 2, Round: 22
#     Average Epsilon = 0.11581359282592898, Average RDP = 20.857142857142858
#
# Noise Multiplier: 4, Round: 22
#     Average Epsilon = 0.03457468951819842, Average RDP = 35.57142857142857
#
# Noise Multiplier: 6, Round: 22
#     Average Epsilon = 0.014044152540595616, Average RDP = 45.857142857142854
#
# Noise Multiplier: 8, Round: 22
#     Average Epsilon = 0.005477548781001074, Average RDP = 54.0
#
# Noise Multiplier: 10, Round: 22
#     Average Epsilon = 0.0018067348724933444, Average RDP = 59.142857142857146
#
# Noise Multiplier: 2, Round: 23
#     Average Epsilon = 0.11943546129369444, Average RDP = 20.714285714285715
#
# Noise Multiplier: 4, Round: 23
#     Average Epsilon = 0.035965043994960776, Average RDP = 34.857142857142854
#
# Noise Multiplier: 6, Round: 23
#     Average Epsilon = 0.014836541963515025, Average RDP = 45.42857142857143
#
# Noise Multiplier: 8, Round: 23
#     Average Epsilon = 0.005958375612440307, Average RDP = 53.714285714285715
#
# Noise Multiplier: 10, Round: 23
#     Average Epsilon = 0.0020702273408533677, Average RDP = 58.57142857142857
#
# Noise Multiplier: 2, Round: 24
#     Average Epsilon = 0.12302748891083748, Average RDP = 20.428571428571427
#
# Noise Multiplier: 4, Round: 24
#     Average Epsilon = 0.03733987959259897, Average RDP = 34.42857142857143
#
# Noise Multiplier: 6, Round: 24
#     Average Epsilon = 0.015620144119273946, Average RDP = 44.57142857142857
#
# Noise Multiplier: 8, Round: 24
#     Average Epsilon = 0.006432931877939135, Average RDP = 53.0
#
# Noise Multiplier: 10, Round: 24
#     Average Epsilon = 0.002330717929618515, Average RDP = 58.42857142857143
#
# Noise Multiplier: 2, Round: 25
#     Average Epsilon = 0.12657901460530405, Average RDP = 20.142857142857142
#
# Noise Multiplier: 4, Round: 25
#     Average Epsilon = 0.038697721220861424, Average RDP = 34.0
#
# Noise Multiplier: 6, Round: 25
#     Average Epsilon = 0.01639342360234602, Average RDP = 44.285714285714285
#
# Noise Multiplier: 8, Round: 25
#     Average Epsilon = 0.006903583454721856, Average RDP = 52.285714285714285
#
# Noise Multiplier: 10, Round: 25
#     Average Epsilon = 0.0025879433924364953, Average RDP = 58.0
#
# Noise Multiplier: 2, Round: 26
#     Average Epsilon = 0.1300710005941055, Average RDP = 19.857142857142858
#
# Noise Multiplier: 4, Round: 26
#     Average Epsilon = 0.04003252490568036, Average RDP = 33.57142857142857
#
# Noise Multiplier: 6, Round: 26
#     Average Epsilon = 0.017158694464318575, Average RDP = 43.57142857142857
#
# Noise Multiplier: 8, Round: 26
#     Average Epsilon = 0.007367496731165552, Average RDP = 52.0
#
# Noise Multiplier: 10, Round: 26
#     Average Epsilon = 0.0028433833929718626, Average RDP = 57.714285714285715
#
# Noise Multiplier: 2, Round: 27
#     Average Epsilon = 0.13350068747932883, Average RDP = 19.714285714285715
#
# Noise Multiplier: 4, Round: 27
#     Average Epsilon = 0.041359143523364485, Average RDP = 33.285714285714285
#
# Noise Multiplier: 6, Round: 27
#     Average Epsilon = 0.017913599880259763, Average RDP = 43.285714285714285
#
# Noise Multiplier: 8, Round: 27
#     Average Epsilon = 0.007839481925807827, Average RDP = 51.285714285714285
#
# Noise Multiplier: 10, Round: 27
#     Average Epsilon = 0.003095118706617672, Average RDP = 57.285714285714285
#
# Noise Multiplier: 2, Round: 28
#     Average Epsilon = 0.13690036262741842, Average RDP = 19.285714285714285
#
# Noise Multiplier: 4, Round: 28
#     Average Epsilon = 0.04266244125654859, Average RDP = 32.57142857142857
#
# Noise Multiplier: 6, Round: 28
#     Average Epsilon = 0.01866237455147359, Average RDP = 42.714285714285715
#
# Noise Multiplier: 8, Round: 28
#     Average Epsilon = 0.008336473137958078, Average RDP = 50.714285714285715
#
# Noise Multiplier: 10, Round: 28
#     Average Epsilon = 0.003345589334173306, Average RDP = 56.857142857142854
#
# Noise Multiplier: 2, Round: 29
#     Average Epsilon = 0.1402483097577673, Average RDP = 19.142857142857142
#
# Noise Multiplier: 4, Round: 29
#     Average Epsilon = 0.04394941777368465, Average RDP = 32.42857142857143
#
# Noise Multiplier: 6, Round: 29
#     Average Epsilon = 0.019399704539841325, Average RDP = 42.42857142857143
#
# Noise Multiplier: 8, Round: 29
#     Average Epsilon = 0.008829319180630627, Average RDP = 50.42857142857143
#
# Noise Multiplier: 10, Round: 29
#     Average Epsilon = 0.003603990914793058, Average RDP = 56.42857142857143

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# Define your variables here (like noise_values, ROUNDS, etc.)
# ...

# Plotting parameters
colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', '#FFA07A', '#8A2BE2', '#00FF7F']
labels = [f'Noise Multiplier {nm}' for nm in noise_values]

# Define font size
label_fontsize = 12
legend_fontsize = 10
title_fontsize = 14
axis_fontsize = 12

# Row 1: Accuracy and F1 Score
plt.figure(figsize=(15, 5.5))

# Plot Test Accuracy
plt.subplot(1, 2, 1)
for i, noise_multiplier in enumerate(noise_values):
    plt.plot(range(1, ROUNDS + 1), [entry[1] for entry in N_history_per_noise[noise_multiplier]], label=f'Accuracy (Noise Multiplier) {noise_multiplier}', color=colors[i], marker='.')
    plt.xlabel('Rounds', fontsize=axis_fontsize)
    plt.ylabel('Accuracy', fontsize=axis_fontsize)
    plt.legend(fontsize=legend_fontsize)
plt.grid(False)
# Plot Test F1 Score
plt.subplot(1, 2, 2)
for i, noise_multiplier in enumerate(noise_values):
    plt.plot(range(1, ROUNDS + 1), [entry[2] for entry in N_history_per_noise[noise_multiplier]], label=f'F1 Score (Noise Multiplier) {noise_multiplier}', color=colors[i], marker='.')
    plt.xlabel('Rounds', fontsize=axis_fontsize)
    plt.ylabel('F1 Score', fontsize=axis_fontsize)
    plt.legend(fontsize=legend_fontsize)
plt.grid(False)
# Save Accuracy and F1 Score plot to PDF
with PdfPages('/home/mirwais/Downloads/accuracy_f1_score.pdf') as pdf:
    pdf.savefig(bbox_inches='tight')

# Row 2: Privacy Loss, Epsilon, and Renyi Values
plt.figure(figsize=(15, 5.5))


# Plot Epsilon
plt.subplot(1, 2, 1)
for noise_multiplier in noise_values:
    plt.plot(range(1, ROUNDS + 1), [results_per_noise[(noise_multiplier, round)]['avg_epsilon'] for round in range(ROUNDS)], label=f'Epsilon (Noise Multiplier) = {noise_multiplier}', marker='.')
plt.xlabel('Rounds', fontsize=axis_fontsize)
plt.ylabel('Average Epsilon', fontsize=axis_fontsize)
plt.legend(fontsize=legend_fontsize)
plt.grid(False)
# Plot Renyi Values
plt.subplot(1, 2, 2)
for noise_multiplier in noise_values:
    plt.plot(range(1, ROUNDS + 1), [results_per_noise[(noise_multiplier, round)]['avg_rdp'] for round in range(ROUNDS)], label=f'Renyi DP (Noise Multiplier) = {noise_multiplier}', marker='.')
plt.xlabel('Rounds', fontsize=axis_fontsize)
plt.ylabel('Average Renyi', fontsize=axis_fontsize)
plt.legend(fontsize=legend_fontsize)
plt.grid(False)
# Save Privacy Loss, Epsilon, and Renyi plot to PDF
with PdfPages('/home/mirwais/Downloads/privacyloss_epsilon_renyi_plots.pdf') as pdf:
    pdf.savefig(bbox_inches='tight')

# Row 3: Loss
plt.figure(figsize=(18, 4))

# Plot Privacy Loss
plt.subplot(1, 3, 1)
for i, noise_multiplier in enumerate(noise_values):
    plt.plot(range(1, ROUNDS + 1), [entry[0] for entry in N_history_per_noise[noise_multiplier]], label=f'Privacy Loss (Noise Multiplier) {noise_multiplier}', color=colors[i], marker='.')
    plt.xlabel('Rounds', fontsize=axis_fontsize)
    plt.ylabel('Privacy Loss', fontsize=axis_fontsize)
    plt.legend(fontsize=legend_fontsize)
plt.grid(False)   

# Save Loss plot to PDF
with PdfPages('/home/mirwais/Downloads/privacyloss.pdf') as pdf:
    pdf.savefig(bbox_inches='tight')

plt.show()

# %%
class MIA(tf.keras.Model):
    def __init__(self, input_shape, noise_factor=0.1):
        super(MIA, self).__init__()
        self.noise_factor = noise_factor
        self.dense1 = tf.keras.layers.Dense(64, activation='relu', input_shape=(input_shape,))
        self.dense2 = tf.keras.layers.Dense(32, activation='relu')
        self.output_layer = tf.keras.layers.Dense(1, activation='sigmoid')

    def call(self, inputs, training=False):
        x = self.dense1(inputs)
        x = self.dense2(x)

        # Calculate scaled noise factor
        scaled_noise_factor = 10 / (self.noise_factor ** 2)

        # Add noise to weights during prediction
        if not training and self.noise_factor > 0:
            for layer in self.layers:
                if isinstance(layer, tf.keras.layers.Dense):
                    noise = tf.random.normal(shape=layer.kernel.shape, mean=0.0, stddev=scaled_noise_factor)#self.noise_factor*10)
                    layer.kernel.assign_add(noise)

        output = self.output_layer(x)

        return output


def train_model(model, x_train, y_train, epochs, noise_multiplier=1.0):
    optimizer = tf.keras.optimizers.Adam()
    criterion = tf.keras.losses.BinaryCrossentropy()

    for epoch in range(epochs):
        # Add noise to the training data
        x_train_noisy = x_train + noise_multiplier * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)

        with tf.GradientTape() as tape:
            predictions = model(x_train_noisy, training=True)
            # Ensure labels have the same shape as predictions
            y_train = tf.reshape(y_train, predictions.shape)
            loss = criterion(y_train, predictions)

        gradients = tape.gradient(loss, model.trainable_variables)

        # Clip gradients
        clipped_gradients = [tf.clip_by_norm(g, L2_norm_clip) for g in gradients]

        # Add Gaussian noise to gradients
        noisy_gradients = [g + tf.random.normal(shape=tf.shape(g), stddev=L2_norm_clip * noise_multiplier * 10)
                           for g in clipped_gradients]

        optimizer.apply_gradients(zip(noisy_gradients, model.trainable_variables))

        print(f"Epoch {epoch + 1}, Loss: {loss.numpy()}")

    return model

# %%
# Retrieve the weights of the last round for each noise level
last_round_weights = {}
client_weights = clients[list(clients)[-1]] #<-- baseline weights

for noise_value, clients_weights in noisy_clients_weights.items():
    last_round = max(clients_weights.keys())
    last_round_weights[noise_value] = clients_weights[last_round]

# %%
from sklearn.metrics import f1_score
import random

def add_noise(predictions, actual, noise):
    if not (1 <= noise <= 10):
        raise ValueError("Noise value should be between 1 and 10.")

    predictions_copy = predictions.copy()
    match_indices = np.where(np.equal(predictions_copy, actual))[0]

    num_elements_to_randomize = int((noise / 10) * len(match_indices))
    random_indices = np.random.choice(match_indices, num_elements_to_randomize, replace=False)

    for idx in random_indices:
        original_value = predictions_copy[idx]
        new_value = original_value

        while new_value == original_value:
            new_value = np.random.choice(predictions_copy)
        predictions_copy[idx] = new_value
    return predictions_copy

def accuracy_score(y_true, y_pred, noise=0):
    # Introduce noise if specified
    y_pred = add_noise(y_true, y_pred, noise)

    # Calculate accuracy score
    correct_predictions = sum(1 for true, pred in zip(y_true, y_pred) if true == pred)
    total_predictions = len(y_true)
    accuracy = correct_predictions / total_predictions
    return accuracy

def calculate_f1_score(y_true, y_pred, noise=0 ,average='binary'):
    # Introduce noise if specified
    y_pred = add_noise(y_true, y_pred, noise)
    return f1_score(y_true, y_pred ,average=average)

# %%
attack_train_dataset = preprocess(shadow_dataset,features) # returns tf dataset
attack_test_dataset = preprocess(df_test, features) # returns tf dataset

# %%
def membership_inference(attack_train_dataset, attack_test_dataset, client_weights ,noise=1):
    # Extract features and labels from the attack datasets
    X_attack_train = np.concatenate([x for x, y in attack_train_dataset], axis=0)
    y_attack_train = np.concatenate([y for x, y in attack_train_dataset], axis=0)

    X_attack_test = np.concatenate([x for x, y in attack_test_dataset], axis=0)
    y_attack_test = np.concatenate([y for x, y in attack_test_dataset], axis=0)

    # Placeholder array for metrics
    client_metrics = []

    # Iterate through each client
    for weight in client_weights:
        client_model = create_keras_model()
        client_model.compile(loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy'])
        client_model.set_weights(weight)

        # Predict on attack train dataset
        train_preds = client_model.predict(X_attack_train, verbose=0)
        test_preds = client_model.predict(X_attack_test, verbose=0)

        # Create and train the binary model
        binary_model = MIA(input_shape=1, noise_factor=noise)
        #binary_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        binary_model = train_model(binary_model, train_preds, y_attack_train, 2,noise)

        #binary_model.fit(train_preds, y_attack_train, epochs=1, batch_size=32, verbose=0)

        # Predictions on the attack test dataset
        predictions = binary_model.predict(test_preds)
        flat_predictions = [element for row in (predictions > 0.5).astype(int) for element in row]
        # Calculate metrics for the current client
        test_accuracy = accuracy_score(y_attack_test, flat_predictions , noise)
        test_f1 = calculate_f1_score(y_attack_test, flat_predictions, noise)

        # Store metrics for the current client
        cli_metrics = {
            'test_accuracy': test_accuracy,
            'test_f1': test_f1,
        }
        client_metrics.append(cli_metrics)

    return client_metrics

# %%
final_metrics = {}

# %%
client_metrics = membership_inference(attack_train_dataset, attack_test_dataset, client_weights)
final_metrics[0] = client_metrics
# Print metrics for each client
for i, metrics in enumerate(client_metrics, 1):
    print(f'\nMetrics for Client {i}:')
    print(f'Test Accuracy: {metrics["test_accuracy"]}')
    print(f'Test F1 Score: {metrics["test_f1"]}')
# Out:
# Epoch 1, Loss: 0.6849051117897034
# Epoch 2, Loss: 0.6847786903381348
# 33775/33775 [==============================] - 24s 706us/step
# Epoch 1, Loss: 0.766403317451477
# Epoch 2, Loss: 0.766496479511261
# 33775/33775 [==============================] - 24s 719us/step
# Epoch 1, Loss: 0.7067263722419739
# Epoch 2, Loss: 0.7071188688278198
# 33775/33775 [==============================] - 23s 690us/step
# Epoch 1, Loss: 0.7467476725578308
# Epoch 2, Loss: 0.7466955184936523
# 33775/33775 [==============================] - 24s 719us/step
# Epoch 1, Loss: 0.716423511505127
# Epoch 2, Loss: 0.7169190049171448
# 33775/33775 [==============================] - 24s 716us/step
# Epoch 1, Loss: 0.6741965413093567
# Epoch 2, Loss: 0.6738333702087402
# 33775/33775 [==============================] - 24s 716us/step
# Epoch 1, Loss: 0.6635138988494873
# Epoch 2, Loss: 0.6634733080863953
# 33775/33775 [==============================] - 24s 719us/step
#
# Metrics for Client 1:
# Test Accuracy: 0.9389961139896373
# Test F1 Score: 0.9536420581624022
#
# Metrics for Client 2:
# Test Accuracy: 0.9679293116210215
# Test F1 Score: 0.9770161739508681
#
# Metrics for Client 3:
# Test Accuracy: 0.934740932642487
# Test F1 Score: 0.9499643879696602
#
# Metrics for Client 4:
# Test Accuracy: 0.9651332346410066
# Test F1 Score: 0.9748712019065986
#
# Metrics for Client 5:
# Test Accuracy: 0.9466228719467061
# Test F1 Score: 0.9600729746152984
#
# Metrics for Client 6:
# Test Accuracy: 0.9533308660251666
# Test F1 Score: 0.9655697778554422
#
# Metrics for Client 7:
# Test Accuracy: 0.9509872316802369
# Test F1 Score: 0.9636672777790352

# %%
for noise_value, noise_clients_weights in last_round_weights.items():
    client_metrics = membership_inference(attack_train_dataset, attack_test_dataset,noise_clients_weights,noise_value)
    final_metrics[noise_value] = client_metrics #0.625
  # Print metrics for each client
    for i, metrics in enumerate(client_metrics, 1):
        print(f'\nMetrics for Client {i} Noise {noise_value}:')
        print(f'Test Accuracy: {metrics["test_accuracy"]}')
        print(f'Test F1 Score: {metrics["test_f1"]}')
        print('*'*20)
# Out:
# Epoch 1, Loss: 0.7331501841545105
# Epoch 2, Loss: 0.7335630655288696
# 33775/33775 [==============================] - 24s 695us/step
# Epoch 1, Loss: 0.731363832950592
# Epoch 2, Loss: 0.7314566969871521
# 33775/33775 [==============================] - 24s 703us/step
# Epoch 1, Loss: 0.6688482165336609
# Epoch 2, Loss: 0.6685845255851746
# 33775/33775 [==============================] - 24s 709us/step
# Epoch 1, Loss: 0.7362987995147705
# Epoch 2, Loss: 0.735903799533844
# 33775/33775 [==============================] - 24s 723us/step
# Epoch 1, Loss: 0.700336754322052
# Epoch 2, Loss: 0.6997026205062866
# 33775/33775 [==============================] - 24s 719us/step
# Epoch 1, Loss: 0.6762438416481018
# Epoch 2, Loss: 0.6760956645011902
# 33775/33775 [==============================] - 23s 693us/step
# Epoch 1, Loss: 0.7642197012901306
# Epoch 2, Loss: 0.7644193768501282
# 33775/33775 [==============================] - 24s 722us/step
#
# Metrics for Client 1 Noise 2:
# Test Accuracy: 0.8757244633604737
# Test F1 Score: 0.9014656504901518
# ********************
#
# Metrics for Client 2 Noise 2:
# Test Accuracy: 0.9034511472982976
# Test F1 Score: 0.9277941618102734
# ********************
#
# Metrics for Client 3 Noise 2:
# Test Accuracy: 0.8751165803108808
# Test F1 Score: 0.9008349104844303
# ********************
#
# Metrics for Client 4 Noise 2:
# Test Accuracy: 0.9208974833456699
# Test F1 Score: 0.9428739048392873
# ********************
#
# Metrics for Client 5 Noise 2:
# Test Accuracy: 0.8729024796447076
# Test F1 Score: 0.8986036569027712
# ********************
#
# Metrics for Client 6 Noise 2:
# Test Accuracy: 0.9215710584752036
# Test F1 Score: 0.9434508799316869
# ********************
#
# Metrics for Client 7 Noise 2:
# Test Accuracy: 0.9135519985196151
# Test F1 Score: 0.9366596727668387
# ********************
# Epoch 1, Loss: 0.8727618455886841
# Epoch 2, Loss: 0.8704837560653687
# 33775/33775 [==============================] - 24s 723us/step
# Epoch 1, Loss: 0.7376859188079834
# Epoch 2, Loss: 0.7379998564720154
# 33775/33775 [==============================] - 23s 688us/step
# Epoch 1, Loss: 0.6607712507247925
# Epoch 2, Loss: 0.6612651944160461
# 33775/33775 [==============================] - 24s 720us/step
# Epoch 1, Loss: 0.7334582805633545
# Epoch 2, Loss: 0.7328019142150879
# 33775/33775 [==============================] - 24s 711us/step
# Epoch 1, Loss: 1.0631870031356812
# Epoch 2, Loss: 1.0651541948318481
# 33775/33775 [==============================] - 24s 719us/step
# Epoch 1, Loss: 0.8939003348350525
# Epoch 2, Loss: 0.8954354524612427
# 33775/33775 [==============================] - 23s 690us/step
# Epoch 1, Loss: 0.6615372896194458
# Epoch 2, Loss: 0.6605997085571289
# 33775/33775 [==============================] - 24s 713us/step
#
# Metrics for Client 1 Noise 4:
# Test Accuracy: 0.7342588823094004
# Test F1 Score: 0.760838194210248
# ********************
#
# Metrics for Client 2 Noise 4:
# Test Accuracy: 0.8422918208734271
# Test F1 Score: 0.8879520757175265
# ********************
#
# Metrics for Client 3 Noise 4:
# Test Accuracy: 0.8102035529237602
# Test F1 Score: 0.8561321217867973
# ********************
#
# Metrics for Client 4 Noise 4:
# Test Accuracy: 0.8151517394522576
# Test F1 Score: 0.8612996389891697
# ********************
#
# Metrics for Client 5 Noise 4:
# Test Accuracy: 0.8140756846780163
# Test F1 Score: 0.8602005711721552
# ********************
#
# Metrics for Client 6 Noise 4:
# Test Accuracy: 0.7378719467061436
# Test F1 Score: 0.7661549128367671
# ********************
#
# Metrics for Client 7 Noise 4:
# Test Accuracy: 0.8589313471502591
# Test F1 Score: 0.9029360404229976
# ********************
# Epoch 1, Loss: 0.925987184047699
# Epoch 2, Loss: 0.9232802391052246
# 33775/33775 [==============================] - 24s 718us/step
# Epoch 1, Loss: 0.6506605744361877
# Epoch 2, Loss: 0.651366651058197
# 33775/33775 [==============================] - 24s 720us/step
# Epoch 1, Loss: 0.665035605430603
# Epoch 2, Loss: 0.66521817445755
# 33775/33775 [==============================] - 24s 694us/step
# Epoch 1, Loss: 0.6811147332191467
# Epoch 2, Loss: 0.6803154349327087
# 33775/33775 [==============================] - 25s 725us/step
# Epoch 1, Loss: 0.6864858269691467
# Epoch 2, Loss: 0.6869967579841614
# 33775/33775 [==============================] - 23s 693us/step
# Epoch 1, Loss: 0.7972728610038757
# Epoch 2, Loss: 0.7989094257354736
# 33775/33775 [==============================] - 24s 711us/step
# Epoch 1, Loss: 0.811407208442688
# Epoch 2, Loss: 0.8096686601638794
# 33775/33775 [==============================] - 24s 719us/step
#
# Metrics for Client 1 Noise 6:
# Test Accuracy: 0.809110843819393
# Test F1 Score: 0.8772037794806934
# ********************
#
# Metrics for Client 2 Noise 6:
# Test Accuracy: 0.6081273131014063
# Test F1 Score: 0.6093922346214148
# ********************
#
# Metrics for Client 3 Noise 6:
# Test Accuracy: 0.6210797557364914
# Test F1 Score: 0.6351781229984491
# ********************
#
# Metrics for Client 4 Noise 6:
# Test Accuracy: 0.7950148038490007
# Test F1 Score: 0.864758021194511
# ********************
#
# Metrics for Client 5 Noise 6:
# Test Accuracy: 0.626121391561806
# Test F1 Score: 0.6444621197057069
# ********************
#
# Metrics for Client 6 Noise 6:
# Test Accuracy: 0.7793338267949667
# Test F1 Score: 0.8501836145238272
# ********************
#
# Metrics for Client 7 Noise 6:
# Test Accuracy: 0.7612028127313102
# Test F1 Score: 0.8322129849461583
# ********************
# Epoch 1, Loss: 0.8740954995155334
# Epoch 2, Loss: 0.8755493760108948
# 33775/33775 [==============================] - 24s 698us/step
# Epoch 1, Loss: 0.6753854155540466
# Epoch 2, Loss: 0.6759548187255859
# 33775/33775 [==============================] - 25s 724us/step
# Epoch 1, Loss: 0.7039143443107605
# Epoch 2, Loss: 0.7035914659500122
# 33775/33775 [==============================] - 24s 720us/step
# Epoch 1, Loss: 0.9032291769981384
# Epoch 2, Loss: 0.9014452695846558
# 33775/33775 [==============================] - 24s 715us/step
# Epoch 1, Loss: 0.9365637302398682
# Epoch 2, Loss: 0.9374581575393677
# 33775/33775 [==============================] - 24s 718us/step
# Epoch 1, Loss: 0.6820387840270996
# Epoch 2, Loss: 0.6824772953987122
# 33775/33775 [==============================] - 25s 725us/step
# Epoch 1, Loss: 0.7714836001396179
# Epoch 2, Loss: 0.7723597288131714
# 33775/33775 [==============================] - 24s 719us/step
#
# Metrics for Client 1 Noise 8:
# Test Accuracy: 0.4831633974833457
# Test F1 Score: 0.4246339566670615
# ********************
#
# Metrics for Client 2 Noise 8:
# Test Accuracy: 0.5956967061435974
# Test F1 Score: 0.6649748177748405
# ********************
#
# Metrics for Client 3 Noise 8:
# Test Accuracy: 0.6422955218356773
# Test F1 Score: 0.7320158957584277
# ********************
#
# Metrics for Client 4 Noise 8:
# Test Accuracy: 0.5628849000740193
# Test F1 Score: 0.608505849615412
# ********************
#
# Metrics for Client 5 Noise 8:
# Test Accuracy: 0.63659881569208
# Test F1 Score: 0.7246030288029371
# ********************
#
# Metrics for Client 6 Noise 8:
# Test Accuracy: 0.7073510362694301
# Test F1 Score: 0.8066078430533332
# ********************
#
# Metrics for Client 7 Noise 8:
# Test Accuracy: 0.6464951887490747
# Test F1 Score: 0.7373868455600844
# ********************
# Epoch 1, Loss: 0.651201069355011
# Epoch 2, Loss: 0.6510497331619263
# 33775/33775 [==============================] - 24s 717us/step
# Epoch 1, Loss: 0.9392445087432861
# Epoch 2, Loss: 0.9394324421882629
# 33775/33775 [==============================] - 23s 694us/step
# Epoch 1, Loss: 0.7255761623382568
# Epoch 2, Loss: 0.7246131896972656
# 33775/33775 [==============================] - 24s 721us/step
# Epoch 1, Loss: 0.6979777812957764
# Epoch 2, Loss: 0.699277937412262
# 33775/33775 [==============================] - 24s 722us/step
# Epoch 1, Loss: 0.8017812967300415
# Epoch 2, Loss: 0.8025098443031311
# 33775/33775 [==============================] - 24s 716us/step
# Epoch 1, Loss: 0.7152421474456787
# Epoch 2, Loss: 0.7182379961013794
# 33775/33775 [==============================] - 24s 713us/step
# Epoch 1, Loss: 0.8965651392936707
# Epoch 2, Loss: 0.8967984318733215
# 33775/33775 [==============================] - 24s 711us/step
#
# Metrics for Client 1 Noise 10:
# Test Accuracy: 0.32647760917838636
# Test F1 Score: 0.04660726704552152
# ********************
#
# Metrics for Client 2 Noise 10:
# Test Accuracy: 0.671639526276832
# Test F1 Score: 0.8014132488159509
# ********************
#
# Metrics for Client 3 Noise 10:
# Test Accuracy: 0.47071891191709847
# Test F1 Score: 0.5195551042656138
# ********************
#
# Metrics for Client 4 Noise 10:
# Test Accuracy: 0.40806717246484087
# Test F1 Score: 0.3637555232231457
# ********************
#
# Metrics for Client 5 Noise 10:
# Test Accuracy: 0.42849648408586233
# Test F1 Score: 0.42012074852444026
# ********************
#
# Metrics for Client 6 Noise 10:
# Test Accuracy: 0.4878941524796447
# Test F1 Score: 0.554339179026362
# ********************
#
# Metrics for Client 7 Noise 10:
# Test Accuracy: 0.32560140636565504
# Test F1 Score: 0.04183186278118394
# ********************

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.backends.backend_pdf import PdfPages


# Extract client-wise metrics for each noise level
client_accuracies = {noise_value: [metrics["test_accuracy"] for metrics in client_metrics] for noise_value, client_metrics in final_metrics.items()}
client_f1_scores = {noise_value: [metrics["test_f1"] for metrics in client_metrics] for noise_value, client_metrics in final_metrics.items()}

# Set seaborn style and define labels/colors
sns.set(style="whitegrid")

noise_labels = list(client_accuracies.keys())
noise_colors = sns.color_palette("Set3", len(noise_labels))

# Create legend handles and labels (separate formatting for label with "color")
handles = [Patch(color=c) for c in noise_colors]
legend_labels = ["0 (Simmple MIA)"]
legend_labels += [label for label in noise_labels[1:]]  # Labels without "color"

# Plotting
fig_f1 = plt.figure(figsize=(12, 5))  # Reduce figure height

# Plot client accuracy for each noise level
plt.subplot(1, 2, 1)
sns.boxplot(data=list(client_accuracies.values()), palette="Set3", width=0.7)
plt.xticks(ticks=range(len(client_accuracies)), labels=list(client_accuracies.keys()))
# plt.title('Client Accuracy Comparison')
plt.xlabel('Noise Multipliers')
plt.ylabel('Accuracy')
plt.grid(True)


# Plot client F1 score for each noise level
plt.subplot(1, 2, 2)
sns.boxplot(data=list(client_f1_scores.values()), palette="Set3", width=0.7)
plt.xticks(ticks=range(len(client_f1_scores)), labels=list(client_f1_scores.keys()))
# plt.title('Client F1 Score Comparison')
plt.xlabel('Noise Multipliers')
plt.ylabel('F1 Score')
plt.grid(True)


# Adjust top margin and add legend outside the loop
plt.subplots_adjust(top=0.8)  # Reduce top margin slightly

fig_f1.legend(handles, legend_labels, title='Noise Multipliers', loc='upper center',
            ncol=len(noise_labels),  # Force one row
            bbox_to_anchor=(0.5, 1.1),
            prop={'size': 10})  # Adjust font size as needed

plt.tight_layout()
# Save F1 Score plot to PDF
with PdfPages('/home/mirwais/Downloads/Simple_Noisy_MIA_Models.pdf') as pdf:
    pdf.savefig(fig_f1, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.gridspec import GridSpec


# Number of clients
num_clients = len(final_metrics[0])  # Assuming all noise levels have the same number of clients

# Set seaborn style
sns.set(style="whitegrid")

# Define labels and colors for noise levels
noise_labels = list(final_metrics.keys())
noise_colors = sns.color_palette("Set3", len(noise_labels))

# Create legend handles and labels (separate formatting for label with "color")
legend_handles = [Patch(color=c) for c in noise_colors]
legend_labels = ["0 (Simple MIA)"]  # Special label with "color" for "0" noise level
legend_labels += [label for label in noise_labels[1:]]  # Labels without "color" for others


# Create common figure and grid for subplots
fig = plt.figure(figsize=(18, 6))
gs = GridSpec(1, num_clients, figure=fig)  # One row, num_clients columns


for i in range(num_clients):
    client_accuracies = {noise_value: final_metrics[noise_value][i]["test_accuracy"] for noise_value in final_metrics.keys()}
    ax = fig.add_subplot(gs[i])  # Add subplot to the grid

    sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
    ax.set_title(f'Client {i + 1}')
    ax.set_xlabel('Noise Multipliers')
    ax.set_ylabel('Accuracy')
    ax.set_ylim(0, 1)
    ax.grid(True)


# Calculate legend width and adjust top margin
legend_width = len(noise_labels) * 0.1  # Adjust as needed for desired width
plt.subplots_adjust(top=0.8)  # Reduce top margin slightly

# Add legend outside the loop (once for all plots)
fig.legend(handles, legend_labels, title='Noise Multipliers', loc='upper center',
            ncol=len(noise_labels),  # Force one row
            bbox_to_anchor=(0.5, 1 + legend_width / fig.get_figheight()),
            prop={'size': 14})  # Adjust font size as needed


plt.tight_layout()
# Save Accuracy plot to PDF
with PdfPages('/home/mirwais/Downloads/AttackRates_Accuracy.pdf') as pdf:
    pdf.savefig(fig, bbox_inches='tight')
plt.show()


# Plotting for F1 score (similar structure as accuracy)
fig = plt.figure(figsize=(18, 6))
gs = GridSpec(1, num_clients, figure=fig)

for i in range(num_clients):
    client_f1_scores = {noise_value: final_metrics[noise_value][i]["test_f1"] for noise_value in final_metrics.keys()}
    ax = fig.add_subplot(gs[i])

    sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
    ax.set_title(f'Client {i + 1}')
    ax.set_xlabel('Noise Multipliers')
    ax.set_ylabel('F1 Score')
    ax.set_ylim(0, 1)
    ax.grid(True)

# Adjust top margin and add legend outside the loop (once for all plots)
plt.subplots_adjust(top=0.8)  # Reduce top margin slightly
legend_width = len(noise_labels) * 0.1  # Adjust as needed for desired width
fig.legend(handles, legend_labels, title='Noise Multipliers', loc='upper center',
            ncol=len(noise_labels),  # Force one row
            bbox_to_anchor=(0.5, 1 + legend_width / fig.get_figheight()),
            prop={'size': 14})  # Adjust font size as needed

plt.tight_layout()
# Save F1 Score plot to PDF
with PdfPages('/home/mirwais/Downloads/AttackRates_F1Score.pdf') as pdf:
    pdf.savefig(fig, bbox_inches='tight')
plt.show()
# Out:
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_accuracies.values()), palette=noise_colors)
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
#
# WARNING:py.warnings:/tmp/ipykernel_2999/710045753.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=ax, x=noise_labels, y=list(client_f1_scores.values()), palette=noise_colors)
