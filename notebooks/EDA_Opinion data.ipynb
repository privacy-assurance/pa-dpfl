# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('~/Desktop/PhD Docs/Papers/Dataset/Dataset_AsiaF/Survey of The Afghan Peoples.csv')

# %%
df.tail()
# Out:
#       '"m1"'  '"i1"'  '"i2"'  '"m2"'  '"m3"'        '"m4"'        '"m5"'  \
# 9266    9764       2       4       1       9  '"Central/"'  '"Shahrist"'
# 9267    9765       3       5       1       9  '"Central/"'  '"Shahrist"'
# 9268    9766       4       6       1       9  '"Central/"'  '"Shahrist"'
# 9269    9767       5       7       1       9  '"Central/"'  '"Shahrist"'
# 9270    9768       6       8       1       9  '"Central/"'  '"Shahrist"'
#
#            '"m6a"'    '"m6b"'        '"m7"'  ...  '"wgt1"'      '"wgt2"'  \
# 9266  '"Villages"'  '"Rural"'  '"Dehkondi"'  ...      1062  '"Central/"'
# 9267  '"Villages"'  '"Rural"'  '"Dehkondi"'  ...      1062  '"Central/"'
# 9268  '"Villages"'  '"Rural"'  '"Dehkondi"'  ...      1062  '"Central/"'
# 9269  '"Villages"'  '"Rural"'  '"Dehkondi"'  ...      1062  '"Central/"'
# 9270  '"Villages"'  '"Rural"'  '"Dehkondi"'  ...      1062  '"Central/"'
#
#        '"wgt3"'     '"wgt4"'  Unnamed: 311 Unnamed: 312  Unnamed: 313  \
# ...

# %%
user_counts = dataset.groupby('user_id').size()
user_counts.plot(kind='bar', width=0.7)  # Adjust the width parameter as needed

# Add values on top of each bar with a bit of space
for i, count in enumerate(user_counts):
    plt.text(i, count + 0.1, f'{count}', ha='center', va='bottom')

# Customize axis labels
plt.xlabel('User_ID (Clients)')
plt.ylabel('Number of Data Samples')

# Save the plot to a PDF file
plt.savefig('/home/mirwais/Downloads/Survey_data_distribution.pdf', bbox_inches='tight')
plt.show()

# %%
sns.catplot(x='q1', data=df, kind="count",height=7, aspect=1.5)
plt.title("Do you think Things in Afghanistan Today are Going in the Right or Wrong Direction",size=13,weight="bold")
sns.set_theme(style="darkgrid")

# %%
df['d1'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
palette3 ={"Female": "C0", "Male": "C1"}
races = ['Right di', 'Wrong di', 'Refused', 'Dont kn']
palette4 ={'Right di':"C0", 'Wrong di':"C1", 'Dont kn':"C2", 'Refused':"C3"}

plt.figure(figsize=(15, 8))
for r in races:
    sns.histplot(x='q1', hue="d1", multiple="stack", data=df[df['q1']==r], palette=palette3, 
                 stat='count', shrink=.5)
    plt.title("By Gender and Openion",size=18,weight="bold")

# %%
sns.catplot(x='q16', data=df, kind="count",height=7, aspect=1.5)
plt.title("Which of these groups would you say is most responsible for providing security?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q17c', data=df, kind="count",height=7, aspect=1.5)
plt.title("The ANA Protects Civilians",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q17a', data=df, kind="count",height=7, aspect=1.5)
plt.title("The ANA is honest and fair with Afghan Peoples",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q17b', data=df, kind="count",height=7, aspect=1.5)
plt.title("The ANA helps improve security in Afghanistan",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q21', data=df, kind="count",height=7, aspect=1.5)
plt.title("Have you or anyone in your family suffered from violence or criminal act in the past",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q27a', data=df, kind="count",height=7, aspect=1.5)
plt.title("You think corruption is a major problem in your life",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q27e', data=df, kind="count",height=7, aspect=1.5)
plt.title("You think corruption is a problem in Afghanistan",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q28i', data=df, kind="count",height=7, aspect=1.5)
plt.title("How often you had asked to give money, a gift or perform a fevor to get a job",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q28h', data=df, kind="count",height=7, aspect=1.8)
plt.title("How often you had asked to give money, a gift or perform a fevor in public healthcare services",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q28j', data=df, kind="count",height=7, aspect=1.8)
plt.title("How often you had asked to give money, a gift or perform a fevor to get addmission in school/University",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q30', data=df, kind="count",height=7, aspect=1.8)
plt.title("How satisfied or dissatisfied are you with the way democracy works in Afghanistan",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q31a', data=df, kind="count",height=7, aspect=1.8)
plt.title("whether you would participate in the Voting of national election",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q31g', data=df, kind="count",height=7, aspect=1.8)
plt.title("whether would you travel from one part of the country to another part",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q38', data=df, kind="count",height=7, aspect=1.8)
plt.title("Please tell me if you happened to have voted in The Presidential Election of 1388",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q51', data=df, kind="count",height=7, aspect=1.6)
plt.title("In general, do you think the most recent election in Afghanistan was free and fair, or not?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='q76', data=df, kind="count",height=7, aspect=1.6)
plt.title("women should decide or should men decide for women who they should vote for?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='d3', data=df, kind="count",height=7, aspect=1.6)
plt.title("What are you doing?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='d5', data=df, kind="count",height=7, aspect=1.6)
plt.title("which period was better for you economically",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='d11', data=df, kind="count",height=7, aspect=1.6)
plt.title("Which ethnic group do you belong to?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='d14b', data=df, kind="count",height=7, aspect=2)
plt.title("which of the following categories best represents your average total family monthly income?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
sns.catplot(x='d15', data=df, kind="count",height=7, aspect=1.5)
plt.title("Do female members of the family contribute to this household income, or not?",size=14,weight="bold")
sns.set_theme(style="darkgrid")

# %%
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# modelling
model = LinearRegression()
model.fit(x, y)
print('intercept:', model.intercept_)
print('slope:', model.coef_)

# scoring
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# intercept: 5.633333333333329
# slope: [0.54]
# coefficient of determination: 0.715875613747954

# %%
sns.catplot(x='q55', data=df, kind="count",height=7, aspect=1.5)
plt.title("Reconciliation efforts between the Afghan Gov and armed opposition groups can help to stabilize the country",size=14,weight="bold")
sns.set_theme(style="darkgrid")
